# %% [markdown]
# __Date:__ 03/07/2023
# <br>__Author:__ Yaren Bilge Kaya
# <br>__Project:__ Routing Strategies for Equitable Service Coordination
#
# <br>__Department:__ Industrial Engineering
# <br>__University:__ Northeastern University
# <br>__Adviser:__ Dr. Kayse Lee Maass

# %%
#Libraries
import numpy as np
import pandas as pd
import random
from numpy import random
import statistics
from statistics import mean

from pandas import ExcelWriter
from pandas import ExcelFile

# %%
import seaborn as sns

from pingouin import ttest
from statsmodels.stats.proportion import proportions_ztest

from scipy.stats import truncnorm
from statsmodels.stats.weightstats import ttest_ind

import matplotlib.pyplot as plt

plt.rc('text', usetex=True)
plt.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]
# Out:
# <ipython-input-2-99aeb41df6cb>:12: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   plt.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]

# %%
#Replication 1
#System overall metrics 
df_rmi_system_0 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '1')  
df_rmi_system_0 = df_rmi_system_0.iloc[1:6,2:9]

#Number of youth arriving
df_rmi_arriving_0 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '1')  
df_rmi_arriving_0 = df_rmi_arriving_0.iloc[8:19,2:8]

#Percent abandonment among abandonments
df_rmi_abandonment_0 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '1')  
df_rmi_abandonment_0 = df_rmi_abandonment_0.iloc[21:32,2:8]

#Wait times
df_rmi_wait_0 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '1')  
df_rmi_wait_0 = df_rmi_wait_0.iloc[47:58,2:8]

#Replication 2
df_rmi_system_1 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '2')  
df_rmi_system_1 = df_rmi_system_1.iloc[1:6,2:9]

df_rmi_arriving_1 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '2')  
df_rmi_arriving_1 = df_rmi_arriving_1.iloc[8:19,2:8]

df_rmi_abandonment_1 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '2')  
df_rmi_abandonment_1 = df_rmi_abandonment_1.iloc[21:32,2:8]

df_rmi_wait_1 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '2')  
df_rmi_wait_1 = df_rmi_wait_1.iloc[47:58,2:8]

df_rmi_system_2 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '3')  
df_rmi_system_2 = df_rmi_system_2.iloc[1:6,2:9]

df_rmi_arriving_2 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '3')  
df_rmi_arriving_2 = df_rmi_arriving_2.iloc[8:19,2:8]

df_rmi_abandonment_2 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '3')  
df_rmi_abandonment_2 = df_rmi_abandonment_2.iloc[21:32,2:8]

df_rmi_wait_2 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '3')  
df_rmi_wait_2 = df_rmi_wait_2.iloc[47:58,2:8]

df_rmi_system_3 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '4')  
df_rmi_system_3 = df_rmi_system_3.iloc[1:6,2:9]

df_rmi_arriving_3 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '4')  
df_rmi_arriving_3 = df_rmi_arriving_3.iloc[8:19,2:8]

df_rmi_abandonment_3 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '4')  
df_rmi_abandonment_3 = df_rmi_abandonment_3.iloc[21:32,2:8]

df_rmi_wait_3 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '4')  
df_rmi_wait_3 = df_rmi_wait_3.iloc[47:58,2:8]

df_rmi_system_4 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '5')  
df_rmi_system_4 = df_rmi_system_4.iloc[1:6,2:9]

df_rmi_arriving_4 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '5')  
df_rmi_arriving_4 = df_rmi_arriving_4.iloc[8:19,2:8]

df_rmi_abandonment_4 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '5')  
df_rmi_abandonment_4 = df_rmi_abandonment_4.iloc[21:32,2:8]

df_rmi_wait_4 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '5')  
df_rmi_wait_4 = df_rmi_wait_4.iloc[47:58,2:8]

df_rmi_system_5 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '6')  
df_rmi_system_5 = df_rmi_system_5.iloc[1:6,2:9]

df_rmi_arriving_5 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '6')  
df_rmi_arriving_5 = df_rmi_arriving_5.iloc[8:19,2:8]

df_rmi_abandonment_5 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '6')  
df_rmi_abandonment_5 = df_rmi_abandonment_5.iloc[21:32,2:8]

df_rmi_wait_5 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '6')  
df_rmi_wait_5 = df_rmi_wait_5.iloc[47:58,2:8]

df_rmi_system_6 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '7')  
df_rmi_system_6 = df_rmi_system_6.iloc[1:6,2:9]

df_rmi_arriving_6 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '7')  
df_rmi_arriving_6 = df_rmi_arriving_6.iloc[8:19,2:8]

df_rmi_abandonment_6 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '7')  
df_rmi_abandonment_6 = df_rmi_abandonment_6.iloc[21:32,2:8]

df_rmi_wait_6 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '7')  
df_rmi_wait_6 = df_rmi_wait_6.iloc[47:58,2:8]

df_rmi_system_7 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '8')  
df_rmi_system_7 = df_rmi_system_7.iloc[1:6,2:9]

df_rmi_arriving_7 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '8')  
df_rmi_arriving_7 = df_rmi_arriving_7.iloc[8:19,2:8]

df_rmi_abandonment_7 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '8')  
df_rmi_abandonment_7 = df_rmi_abandonment_7.iloc[21:32,2:8]

df_rmi_wait_7 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '8')  
df_rmi_wait_7 = df_rmi_wait_7.iloc[47:58,2:8]

df_rmi_system_8 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '9')  
df_rmi_system_8 = df_rmi_system_8.iloc[1:6,2:9]

df_rmi_arriving_8 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '9')  
df_rmi_arriving_8 = df_rmi_arriving_8.iloc[8:19,2:8]

df_rmi_abandonment_8 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '9')  
df_rmi_abandonment_8 = df_rmi_abandonment_8.iloc[21:32,2:8]

df_rmi_wait_8 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '9')  
df_rmi_wait_8 = df_rmi_wait_8.iloc[47:58,2:8]

#Replication 10
df_rmi_system_9 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '10')  
df_rmi_system_9 = df_rmi_system_9.iloc[1:6,2:9]

df_rmi_arriving_9 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '10')  
df_rmi_arriving_9 = df_rmi_arriving_9.iloc[8:19,2:8]

df_rmi_abandonment_9 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '10')  
df_rmi_abandonment_9 = df_rmi_abandonment_9.iloc[21:32,2:8]

df_rmi_wait_9 = pd.read_excel(r'C:\Users\yaren\Desktop\Dissertation\Routing Strategies\Outputs\March 23\RMIOutputs_03.23.23.xlsx', 
                     sheet_name = '10')  
df_rmi_wait_9 = df_rmi_wait_9.iloc[47:58,2:8]

# %% [markdown]
# __For the whole system metrics__

# %%
#Datasets for abandonment percentage
df_rmi_abandonment_female = [df_rmi_abandonment_0.iloc[0,5]]*10 + [df_rmi_abandonment_1.iloc[0,5]]*10 + [df_rmi_abandonment_2.iloc[0,5]]*10 + [df_rmi_abandonment_3.iloc[0,5]]*10+ [df_rmi_abandonment_4.iloc[0,5]]*10 + [df_rmi_abandonment_5.iloc[0,5]]*10+ [df_rmi_abandonment_6.iloc[0,5]]*10 + [df_rmi_abandonment_7.iloc[0,5]]*10+ [df_rmi_abandonment_8.iloc[0,5]]*10 + [df_rmi_abandonment_9.iloc[0,5]]*10
df_rmi_abandonment_male = [df_rmi_abandonment_0.iloc[1,5]]*10 + [df_rmi_abandonment_1.iloc[1,5]]*10 + [df_rmi_abandonment_2.iloc[1,5]]*10 + [df_rmi_abandonment_3.iloc[1,5]]*10+ [df_rmi_abandonment_4.iloc[1,5]]*10 + [df_rmi_abandonment_5.iloc[1,5]]*10+ [df_rmi_abandonment_6.iloc[1,5]]*10 + [df_rmi_abandonment_7.iloc[1,5]]*10+ [df_rmi_abandonment_8.iloc[1,5]]*10 + [df_rmi_abandonment_9.iloc[1,5]]*10
df_rmi_abandonment_noncis = [df_rmi_abandonment_0.iloc[2,5]]*10 + [df_rmi_abandonment_1.iloc[2,5]]*10 + [df_rmi_abandonment_2.iloc[2,5]]*10 + [df_rmi_abandonment_3.iloc[2,5]]*10+ [df_rmi_abandonment_4.iloc[2,5]]*10 + [df_rmi_abandonment_5.iloc[2,5]]*10+ [df_rmi_abandonment_6.iloc[2,5]]*10 + [df_rmi_abandonment_7.iloc[2,5]]*10+ [df_rmi_abandonment_8.iloc[2,5]]*10 + [df_rmi_abandonment_9.iloc[2,5]]*10

df_rmi_abandonment_older21 = [df_rmi_abandonment_0.iloc[3,5]]*10 + [df_rmi_abandonment_1.iloc[3,5]]*10 + [df_rmi_abandonment_2.iloc[3,5]]*10 + [df_rmi_abandonment_3.iloc[3,5]]*10+ [df_rmi_abandonment_4.iloc[3,5]]*10 + [df_rmi_abandonment_5.iloc[3,5]]*10+ [df_rmi_abandonment_6.iloc[3,5]]*10 + [df_rmi_abandonment_7.iloc[3,5]]*10+ [df_rmi_abandonment_8.iloc[3,5]]*10 + [df_rmi_abandonment_9.iloc[3,5]]*10
df_rmi_abandonment_younger21 = [df_rmi_abandonment_0.iloc[4,5]]*10 + [df_rmi_abandonment_1.iloc[4,5]]*10 + [df_rmi_abandonment_2.iloc[4,5]]*10 + [df_rmi_abandonment_3.iloc[4,5]]*10+ [df_rmi_abandonment_4.iloc[4,5]]*10 + [df_rmi_abandonment_5.iloc[4,5]]*10+ [df_rmi_abandonment_6.iloc[4,5]]*10 + [df_rmi_abandonment_7.iloc[4,5]]*10+ [df_rmi_abandonment_8.iloc[4,5]]*10 + [df_rmi_abandonment_9.iloc[4,5]]*10

df_rmi_abandonment_withchild = [df_rmi_abandonment_0.iloc[5,5]]*10 + [df_rmi_abandonment_1.iloc[5,5]]*10 + [df_rmi_abandonment_2.iloc[5,5]]*10 + [df_rmi_abandonment_3.iloc[5,5]]*10+ [df_rmi_abandonment_4.iloc[5,5]]*10 + [df_rmi_abandonment_5.iloc[5,5]]*10+ [df_rmi_abandonment_6.iloc[5,5]]*10 + [df_rmi_abandonment_7.iloc[5,5]]*10+ [df_rmi_abandonment_8.iloc[5,5]]*10 + [df_rmi_abandonment_9.iloc[5,5]]*10
df_rmi_abandonment_nochild = [df_rmi_abandonment_0.iloc[6,5]]*10 + [df_rmi_abandonment_1.iloc[6,5]]*10 + [df_rmi_abandonment_2.iloc[6,5]]*10 + [df_rmi_abandonment_3.iloc[6,5]]*10+ [df_rmi_abandonment_4.iloc[6,5]]*10 + [df_rmi_abandonment_5.iloc[6,5]]*10+ [df_rmi_abandonment_6.iloc[6,5]]*10 + [df_rmi_abandonment_7.iloc[6,5]]*10+ [df_rmi_abandonment_8.iloc[6,5]]*10 + [df_rmi_abandonment_9.iloc[6,5]]*10

df_rmi_abandonment_immigrant = [df_rmi_abandonment_0.iloc[7,5]]*10 + [df_rmi_abandonment_1.iloc[7,5]]*10 + [df_rmi_abandonment_2.iloc[7,5]]*10 + [df_rmi_abandonment_3.iloc[7,5]]*10+ [df_rmi_abandonment_4.iloc[7,5]]*10 + [df_rmi_abandonment_5.iloc[7,5]]*10+ [df_rmi_abandonment_6.iloc[7,5]]*10 + [df_rmi_abandonment_7.iloc[7,5]]*10+ [df_rmi_abandonment_8.iloc[7,5]]*10 + [df_rmi_abandonment_9.iloc[7,5]]*10
df_rmi_abandonment_notimmigrant = [df_rmi_abandonment_0.iloc[8,5]]*10 + [df_rmi_abandonment_1.iloc[8,5]]*10 + [df_rmi_abandonment_2.iloc[8,5]]*10 + [df_rmi_abandonment_3.iloc[8,5]]*10+ [df_rmi_abandonment_4.iloc[8,5]]*10 + [df_rmi_abandonment_5.iloc[8,5]]*10+ [df_rmi_abandonment_6.iloc[8,5]]*10 + [df_rmi_abandonment_7.iloc[8,5]]*10+ [df_rmi_abandonment_8.iloc[8,5]]*10 + [df_rmi_abandonment_9.iloc[8,5]]*10

df_rmi_abandonment_htvictim = [df_rmi_abandonment_0.iloc[9,5]]*10 + [df_rmi_abandonment_1.iloc[9,5]]*10 + [df_rmi_abandonment_2.iloc[9,5]]*10 + [df_rmi_abandonment_3.iloc[9,5]]*10+ [df_rmi_abandonment_4.iloc[9,5]]*10 + [df_rmi_abandonment_5.iloc[9,5]]*10+ [df_rmi_abandonment_6.iloc[9,5]]*10 + [df_rmi_abandonment_7.iloc[9,5]]*10+ [df_rmi_abandonment_8.iloc[9,5]]*10 + [df_rmi_abandonment_9.iloc[9,5]]*10
df_rmi_abandonment_nothtvictim = [df_rmi_abandonment_0.iloc[10,5]]*10 + [df_rmi_abandonment_1.iloc[10,5]]*10 + [df_rmi_abandonment_2.iloc[10,5]]*10 + [df_rmi_abandonment_3.iloc[10,5]]*10+ [df_rmi_abandonment_4.iloc[10,5]]*10 + [df_rmi_abandonment_5.iloc[10,5]]*10+ [df_rmi_abandonment_6.iloc[10,5]]*10 + [df_rmi_abandonment_7.iloc[10,5]]*10+ [df_rmi_abandonment_8.iloc[10,5]]*10 + [df_rmi_abandonment_9.iloc[10,5]]*10

#Datasets for average wait
df_rmi_wait_female = [df_rmi_wait_0.iloc[0,5]]*10 + [df_rmi_wait_1.iloc[0,5]]*10 + [df_rmi_wait_2.iloc[0,5]]*10 + [df_rmi_wait_3.iloc[0,5]]*10+ [df_rmi_wait_4.iloc[0,5]]*10 + [df_rmi_wait_5.iloc[0,5]]*10+ [df_rmi_wait_6.iloc[0,5]]*10 + [df_rmi_wait_7.iloc[0,5]]*10+ [df_rmi_wait_8.iloc[0,5]]*10 + [df_rmi_wait_9.iloc[0,5]]*10
df_rmi_wait_male = [df_rmi_wait_0.iloc[1,5]]*10 + [df_rmi_wait_1.iloc[1,5]]*10 + [df_rmi_wait_2.iloc[1,5]]*10 + [df_rmi_wait_3.iloc[1,5]]*10+ [df_rmi_wait_4.iloc[1,5]]*10 + [df_rmi_wait_5.iloc[1,5]]*10+ [df_rmi_wait_6.iloc[1,5]]*10 + [df_rmi_wait_7.iloc[1,5]]*10+ [df_rmi_wait_8.iloc[1,5]]*10 + [df_rmi_wait_9.iloc[1,5]]*10
df_rmi_wait_noncis = [df_rmi_wait_0.iloc[2,5]]*10 + [df_rmi_wait_1.iloc[2,5]]*10 + [df_rmi_wait_2.iloc[2,5]]*10 + [df_rmi_wait_3.iloc[2,5]]*10+ [df_rmi_wait_4.iloc[2,5]]*10 + [df_rmi_wait_5.iloc[2,5]]*10+ [df_rmi_wait_6.iloc[2,5]]*10 + [df_rmi_wait_7.iloc[2,5]]*10+ [df_rmi_wait_8.iloc[2,5]]*10 + [df_rmi_wait_9.iloc[2,5]]*10

df_rmi_wait_older21 = [df_rmi_wait_0.iloc[3,5]]*10 + [df_rmi_wait_1.iloc[3,5]]*10 + [df_rmi_wait_2.iloc[3,5]]*10 + [df_rmi_wait_3.iloc[3,5]]*10+ [df_rmi_wait_4.iloc[3,5]]*10 + [df_rmi_wait_5.iloc[3,5]]*10+ [df_rmi_wait_6.iloc[3,5]]*10 + [df_rmi_wait_7.iloc[3,5]]*10+ [df_rmi_wait_8.iloc[3,5]]*10 + [df_rmi_wait_9.iloc[3,5]]*10
df_rmi_wait_younger21 = [df_rmi_wait_0.iloc[4,5]]*10 + [df_rmi_wait_1.iloc[4,5]]*10 + [df_rmi_wait_2.iloc[4,5]]*10 + [df_rmi_wait_3.iloc[4,5]]*10+ [df_rmi_wait_4.iloc[4,5]]*10 + [df_rmi_wait_5.iloc[4,5]]*10+ [df_rmi_wait_6.iloc[4,5]]*10 + [df_rmi_wait_7.iloc[4,5]]*10+ [df_rmi_wait_8.iloc[4,5]]*10 + [df_rmi_wait_9.iloc[4,5]]*10

df_rmi_wait_withchild = [df_rmi_wait_0.iloc[5,5]]*10 + [df_rmi_wait_1.iloc[5,5]]*10 + [df_rmi_wait_2.iloc[5,5]]*10 + [df_rmi_wait_3.iloc[5,5]]*10+ [df_rmi_wait_4.iloc[5,5]]*10 + [df_rmi_wait_5.iloc[5,5]]*10+ [df_rmi_wait_6.iloc[5,5]]*10 + [df_rmi_wait_7.iloc[5,5]]*10+ [df_rmi_wait_8.iloc[5,5]]*10 + [df_rmi_wait_9.iloc[5,5]]*10
df_rmi_wait_nochild = [df_rmi_wait_0.iloc[6,5]]*10 + [df_rmi_wait_1.iloc[6,5]]*10 + [df_rmi_wait_2.iloc[6,5]]*10 + [df_rmi_wait_3.iloc[6,5]]*10+ [df_rmi_wait_4.iloc[6,5]]*10 + [df_rmi_wait_5.iloc[6,5]]*10+ [df_rmi_wait_6.iloc[6,5]]*10 + [df_rmi_wait_7.iloc[6,5]]*10+ [df_rmi_wait_8.iloc[6,5]]*10 + [df_rmi_wait_9.iloc[6,5]]*10

df_rmi_wait_immigrant = [df_rmi_wait_0.iloc[7,5]]*10 + [df_rmi_wait_1.iloc[7,5]]*10 + [df_rmi_wait_2.iloc[7,5]]*10 + [df_rmi_wait_3.iloc[7,5]]*10+ [df_rmi_wait_4.iloc[7,5]]*10 + [df_rmi_wait_5.iloc[7,5]]*10+ [df_rmi_wait_6.iloc[7,5]]*10 + [df_rmi_wait_7.iloc[7,5]]*10+ [df_rmi_wait_8.iloc[7,5]]*10 + [df_rmi_wait_9.iloc[7,5]]*10
df_rmi_wait_notimmigrant = [df_rmi_wait_0.iloc[8,5]]*10 + [df_rmi_wait_1.iloc[8,5]]*10 + [df_rmi_wait_2.iloc[8,5]]*10 + [df_rmi_wait_3.iloc[8,5]]*10+ [df_rmi_wait_4.iloc[8,5]]*10 + [df_rmi_wait_5.iloc[8,5]]*10+ [df_rmi_wait_6.iloc[8,5]]*10 + [df_rmi_wait_7.iloc[8,5]]*10+ [df_rmi_wait_8.iloc[8,5]]*10 + [df_rmi_wait_9.iloc[8,5]]*10

df_rmi_wait_htvictim = [df_rmi_wait_0.iloc[9,5]]*10 + [df_rmi_wait_1.iloc[9,5]]*10 + [df_rmi_wait_2.iloc[9,5]]*10 + [df_rmi_wait_3.iloc[9,5]]*10+ [df_rmi_wait_4.iloc[9,5]]*10 + [df_rmi_wait_5.iloc[9,5]]*10+ [df_rmi_wait_6.iloc[9,5]]*10 + [df_rmi_wait_7.iloc[9,5]]*10+ [df_rmi_wait_8.iloc[9,5]]*10 + [df_rmi_wait_9.iloc[9,5]]*10
df_rmi_wait_nothtvictim = [df_rmi_wait_0.iloc[10,5]]*10 + [df_rmi_wait_1.iloc[10,5]]*10 + [df_rmi_wait_2.iloc[10,5]]*10 + [df_rmi_wait_3.iloc[10,5]]*10+ [df_rmi_wait_4.iloc[10,5]]*10 + [df_rmi_wait_5.iloc[10,5]]*10+ [df_rmi_wait_6.iloc[10,5]]*10 + [df_rmi_wait_7.iloc[10,5]]*10+ [df_rmi_wait_8.iloc[10,5]]*10 + [df_rmi_wait_9.iloc[10,5]]*10

#Datasets for number of youth arriving
df_rmi_arriving_female = [df_rmi_arriving_0.iloc[0,5]]*10 + [df_rmi_arriving_1.iloc[0,5]]*10 + [df_rmi_arriving_2.iloc[0,5]]*10 + [df_rmi_arriving_3.iloc[0,5]]*10+ [df_rmi_arriving_4.iloc[0,5]]*10 + [df_rmi_arriving_5.iloc[0,5]]*10+ [df_rmi_arriving_6.iloc[0,5]]*10 + [df_rmi_arriving_7.iloc[0,5]]*10+ [df_rmi_arriving_8.iloc[0,5]]*10 + [df_rmi_arriving_9.iloc[0,5]]*10
df_rmi_arriving_male = [df_rmi_arriving_0.iloc[1,5]]*10 + [df_rmi_arriving_1.iloc[1,5]]*10 + [df_rmi_arriving_2.iloc[1,5]]*10 + [df_rmi_arriving_3.iloc[1,5]]*10+ [df_rmi_arriving_4.iloc[1,5]]*10 + [df_rmi_arriving_5.iloc[1,5]]*10+ [df_rmi_arriving_6.iloc[1,5]]*10 + [df_rmi_arriving_7.iloc[1,5]]*10+ [df_rmi_arriving_8.iloc[1,5]]*10 + [df_rmi_arriving_9.iloc[1,5]]*10
df_rmi_arriving_noncis = [df_rmi_arriving_0.iloc[2,5]]*10 + [df_rmi_arriving_1.iloc[2,5]]*10 + [df_rmi_arriving_2.iloc[2,5]]*10 + [df_rmi_arriving_3.iloc[2,5]]*10+ [df_rmi_arriving_4.iloc[2,5]]*10 + [df_rmi_arriving_5.iloc[2,5]]*10+ [df_rmi_arriving_6.iloc[2,5]]*10 + [df_rmi_arriving_7.iloc[2,5]]*10+ [df_rmi_arriving_8.iloc[2,5]]*10 + [df_rmi_arriving_9.iloc[2,5]]*10

df_rmi_arriving_older21 = [df_rmi_arriving_0.iloc[3,5]]*10 + [df_rmi_arriving_1.iloc[3,5]]*10 + [df_rmi_arriving_2.iloc[3,5]]*10 + [df_rmi_arriving_3.iloc[3,5]]*10+ [df_rmi_arriving_4.iloc[3,5]]*10 + [df_rmi_arriving_5.iloc[3,5]]*10+ [df_rmi_arriving_6.iloc[3,5]]*10 + [df_rmi_arriving_7.iloc[3,5]]*10+ [df_rmi_arriving_8.iloc[3,5]]*10 + [df_rmi_arriving_9.iloc[3,5]]*10
df_rmi_arriving_younger21 = [df_rmi_arriving_0.iloc[4,5]]*10 + [df_rmi_arriving_1.iloc[4,5]]*10 + [df_rmi_arriving_2.iloc[4,5]]*10 + [df_rmi_arriving_3.iloc[4,5]]*10+ [df_rmi_arriving_4.iloc[4,5]]*10 + [df_rmi_arriving_5.iloc[4,5]]*10+ [df_rmi_arriving_6.iloc[4,5]]*10 + [df_rmi_arriving_7.iloc[4,5]]*10+ [df_rmi_arriving_8.iloc[4,5]]*10 + [df_rmi_arriving_9.iloc[4,5]]*10

df_rmi_arriving_withchild = [df_rmi_arriving_0.iloc[5,5]]*10 + [df_rmi_arriving_1.iloc[5,5]]*10 + [df_rmi_arriving_2.iloc[5,5]]*10 + [df_rmi_arriving_3.iloc[5,5]]*10+ [df_rmi_arriving_4.iloc[5,5]]*10 + [df_rmi_arriving_5.iloc[5,5]]*10+ [df_rmi_arriving_6.iloc[5,5]]*10 + [df_rmi_arriving_7.iloc[5,5]]*10+ [df_rmi_arriving_8.iloc[5,5]]*10 + [df_rmi_arriving_9.iloc[5,5]]*10
df_rmi_arriving_nochild = [df_rmi_arriving_0.iloc[6,5]]*10 + [df_rmi_arriving_1.iloc[6,5]]*10 + [df_rmi_arriving_2.iloc[6,5]]*10 + [df_rmi_arriving_3.iloc[6,5]]*10+ [df_rmi_arriving_4.iloc[6,5]]*10 + [df_rmi_arriving_5.iloc[6,5]]*10+ [df_rmi_arriving_6.iloc[6,5]]*10 + [df_rmi_arriving_7.iloc[6,5]]*10+ [df_rmi_arriving_8.iloc[6,5]]*10 + [df_rmi_arriving_9.iloc[6,5]]*10

df_rmi_arriving_immigrant = [df_rmi_arriving_0.iloc[7,5]]*10 + [df_rmi_arriving_1.iloc[7,5]]*10 + [df_rmi_arriving_2.iloc[7,5]]*10 + [df_rmi_arriving_3.iloc[7,5]]*10+ [df_rmi_arriving_4.iloc[7,5]]*10 + [df_rmi_arriving_5.iloc[7,5]]*10+ [df_rmi_arriving_6.iloc[7,5]]*10 + [df_rmi_arriving_7.iloc[7,5]]*10+ [df_rmi_arriving_8.iloc[7,5]]*10 + [df_rmi_arriving_9.iloc[7,5]]*10
df_rmi_arriving_notimmigrant = [df_rmi_arriving_0.iloc[8,5]]*10 + [df_rmi_arriving_1.iloc[8,5]]*10 + [df_rmi_arriving_2.iloc[8,5]]*10 + [df_rmi_arriving_3.iloc[8,5]]*10+ [df_rmi_arriving_4.iloc[8,5]]*10 + [df_rmi_arriving_5.iloc[8,5]]*10+ [df_rmi_arriving_6.iloc[8,5]]*10 + [df_rmi_arriving_7.iloc[8,5]]*10+ [df_rmi_arriving_8.iloc[8,5]]*10 + [df_rmi_arriving_9.iloc[8,5]]*10

df_rmi_arriving_htvictim = [df_rmi_arriving_0.iloc[9,5]]*10 + [df_rmi_arriving_1.iloc[9,5]]*10 + [df_rmi_arriving_2.iloc[9,5]]*10 + [df_rmi_arriving_3.iloc[9,5]]*10+ [df_rmi_arriving_4.iloc[9,5]]*10 + [df_rmi_arriving_5.iloc[9,5]]*10+ [df_rmi_arriving_6.iloc[9,5]]*10 + [df_rmi_arriving_7.iloc[9,5]]*10+ [df_rmi_arriving_8.iloc[9,5]]*10 + [df_rmi_arriving_9.iloc[9,5]]*10
df_rmi_arriving_nothtvictim = [df_rmi_arriving_0.iloc[10,5]]*10 + [df_rmi_arriving_1.iloc[10,5]]*10 + [df_rmi_arriving_2.iloc[10,5]]*10 + [df_rmi_arriving_3.iloc[10,5]]*10+ [df_rmi_arriving_4.iloc[10,5]]*10 + [df_rmi_arriving_5.iloc[10,5]]*10+ [df_rmi_arriving_6.iloc[10,5]]*10 + [df_rmi_arriving_7.iloc[10,5]]*10+ [df_rmi_arriving_8.iloc[10,5]]*10 + [df_rmi_arriving_9.iloc[10,5]]*10

#Dataset for system overall outputs
df_rmi_abandonment_s0 = [df_rmi_system_0.iloc[0,5]]*10 + [df_rmi_system_1.iloc[0,5]]*10 + [df_rmi_system_2.iloc[0,5]]*10 + [df_rmi_system_3.iloc[0,5]]*10+ [df_rmi_system_4.iloc[0,5]]*10 + [df_rmi_system_5.iloc[0,5]]*10+ [df_rmi_system_6.iloc[0,5]]*10 + [df_rmi_system_7.iloc[0,5]]*10+ [df_rmi_system_8.iloc[0,5]]*10 + [df_rmi_system_9.iloc[0,5]]*10
df_rmi_abandonment_s1 = [df_rmi_system_0.iloc[1,5]]*10 + [df_rmi_system_1.iloc[1,5]]*10 + [df_rmi_system_2.iloc[1,5]]*10 + [df_rmi_system_3.iloc[1,5]]*10+ [df_rmi_system_4.iloc[1,5]]*10 + [df_rmi_system_5.iloc[1,5]]*10+ [df_rmi_system_6.iloc[1,5]]*10 + [df_rmi_system_7.iloc[1,5]]*10+ [df_rmi_system_8.iloc[1,5]]*10 + [df_rmi_system_9.iloc[1,5]]*10
df_rmi_abandonment_s2 = [df_rmi_system_0.iloc[2,5]]*10 + [df_rmi_system_1.iloc[2,5]]*10 + [df_rmi_system_2.iloc[2,5]]*10 + [df_rmi_system_3.iloc[2,5]]*10+ [df_rmi_system_4.iloc[2,5]]*10 + [df_rmi_system_5.iloc[2,5]]*10+ [df_rmi_system_6.iloc[2,5]]*10 + [df_rmi_system_7.iloc[2,5]]*10+ [df_rmi_system_8.iloc[2,5]]*10 + [df_rmi_system_9.iloc[2,5]]*10
df_rmi_abandonment_s3 = [df_rmi_system_0.iloc[3,5]]*10 + [df_rmi_system_1.iloc[3,5]]*10 + [df_rmi_system_2.iloc[3,5]]*10 + [df_rmi_system_3.iloc[3,5]]*10+ [df_rmi_system_4.iloc[3,5]]*10 + [df_rmi_system_5.iloc[3,5]]*10+ [df_rmi_system_6.iloc[3,5]]*10 + [df_rmi_system_7.iloc[3,5]]*10+ [df_rmi_system_8.iloc[3,5]]*10 + [df_rmi_system_9.iloc[3,5]]*10

df_rmi_wait_s0 = [df_rmi_system_0.iloc[0,6]]*10 + [df_rmi_system_1.iloc[0,6]]*10 + [df_rmi_system_2.iloc[0,6]]*10 + [df_rmi_system_3.iloc[0,6]]*10+ [df_rmi_system_4.iloc[0,6]]*10 + [df_rmi_system_5.iloc[0,6]]*10+ [df_rmi_system_6.iloc[0,6]]*10 + [df_rmi_system_7.iloc[0,6]]*10+ [df_rmi_system_8.iloc[0,6]]*10 + [df_rmi_system_9.iloc[0,6]]*10
df_rmi_wait_s1 = [df_rmi_system_0.iloc[1,6]]*10 + [df_rmi_system_1.iloc[1,6]]*10 + [df_rmi_system_2.iloc[1,6]]*10 + [df_rmi_system_3.iloc[1,6]]*10+ [df_rmi_system_4.iloc[1,6]]*10 + [df_rmi_system_5.iloc[1,6]]*10+ [df_rmi_system_6.iloc[1,6]]*10 + [df_rmi_system_7.iloc[1,6]]*10+ [df_rmi_system_8.iloc[1,6]]*10 + [df_rmi_system_9.iloc[1,6]]*10
df_rmi_wait_s2 = [df_rmi_system_0.iloc[2,6]]*10 + [df_rmi_system_1.iloc[2,6]]*10 + [df_rmi_system_2.iloc[2,6]]*10 + [df_rmi_system_3.iloc[2,6]]*10+ [df_rmi_system_4.iloc[2,6]]*10 + [df_rmi_system_5.iloc[2,6]]*10+ [df_rmi_system_6.iloc[2,6]]*10 + [df_rmi_system_7.iloc[2,6]]*10+ [df_rmi_system_8.iloc[2,6]]*10 + [df_rmi_system_9.iloc[2,6]]*10
df_rmi_wait_s3 = [df_rmi_system_0.iloc[3,6]]*10 + [df_rmi_system_1.iloc[3,6]]*10 + [df_rmi_system_2.iloc[3,6]]*10 + [df_rmi_system_3.iloc[3,6]]*10+ [df_rmi_system_4.iloc[3,6]]*10 + [df_rmi_system_5.iloc[3,6]]*10+ [df_rmi_system_6.iloc[3,6]]*10 + [df_rmi_system_7.iloc[3,6]]*10+ [df_rmi_system_8.iloc[3,6]]*10 + [df_rmi_system_9.iloc[3,6]]*10

df_rmi_utilization_s0 = [df_rmi_system_0.iloc[0,3]]*10 + [df_rmi_system_1.iloc[0,3]]*10 + [df_rmi_system_2.iloc[0,3]]*10 + [df_rmi_system_3.iloc[0,3]]*10+ [df_rmi_system_4.iloc[0,3]]*10 + [df_rmi_system_5.iloc[0,3]]*10+ [df_rmi_system_6.iloc[0,3]]*10 + [df_rmi_system_7.iloc[0,3]]*10+ [df_rmi_system_8.iloc[0,3]]*10 + [df_rmi_system_9.iloc[0,3]]*10
df_rmi_utilization_s1 = [df_rmi_system_0.iloc[1,3]]*10 + [df_rmi_system_1.iloc[1,3]]*10 + [df_rmi_system_2.iloc[1,3]]*10 + [df_rmi_system_3.iloc[1,3]]*10+ [df_rmi_system_4.iloc[1,3]]*10 + [df_rmi_system_5.iloc[1,3]]*10+ [df_rmi_system_6.iloc[1,3]]*10 + [df_rmi_system_7.iloc[1,3]]*10+ [df_rmi_system_8.iloc[1,3]]*10 + [df_rmi_system_9.iloc[1,3]]*10
df_rmi_utilization_s2 = [df_rmi_system_0.iloc[2,3]]*10 + [df_rmi_system_1.iloc[2,3]]*10 + [df_rmi_system_2.iloc[2,3]]*10 + [df_rmi_system_3.iloc[2,3]]*10+ [df_rmi_system_4.iloc[2,3]]*10 + [df_rmi_system_5.iloc[2,3]]*10+ [df_rmi_system_6.iloc[2,3]]*10 + [df_rmi_system_7.iloc[2,3]]*10+ [df_rmi_system_8.iloc[2,3]]*10 + [df_rmi_system_9.iloc[2,3]]*10
df_rmi_utilization_s3 = [df_rmi_system_0.iloc[3,3]]*10 + [df_rmi_system_1.iloc[3,3]]*10 + [df_rmi_system_2.iloc[3,3]]*10 + [df_rmi_system_3.iloc[3,3]]*10+ [df_rmi_system_4.iloc[3,3]]*10 + [df_rmi_system_5.iloc[3,3]]*10+ [df_rmi_system_6.iloc[3,3]]*10 + [df_rmi_system_7.iloc[3,3]]*10+ [df_rmi_system_8.iloc[3,3]]*10 + [df_rmi_system_9.iloc[3,3]]*10

df_rmi_queuelen_s0 = [df_rmi_system_0.iloc[0,4]]*10 + [df_rmi_system_1.iloc[0,4]]*10 + [df_rmi_system_2.iloc[0,4]]*10 + [df_rmi_system_3.iloc[0,4]]*10+ [df_rmi_system_4.iloc[0,4]]*10 + [df_rmi_system_5.iloc[0,4]]*10+ [df_rmi_system_6.iloc[0,4]]*10 + [df_rmi_system_7.iloc[0,4]]*10+ [df_rmi_system_8.iloc[0,4]]*10 + [df_rmi_system_9.iloc[0,4]]*10
df_rmi_queuelen_s1 = [df_rmi_system_0.iloc[1,4]]*10 + [df_rmi_system_1.iloc[1,4]]*10 + [df_rmi_system_2.iloc[1,4]]*10 + [df_rmi_system_3.iloc[1,4]]*10+ [df_rmi_system_4.iloc[1,4]]*10 + [df_rmi_system_5.iloc[1,4]]*10+ [df_rmi_system_6.iloc[1,4]]*10 + [df_rmi_system_7.iloc[1,4]]*10+ [df_rmi_system_8.iloc[1,4]]*10 + [df_rmi_system_9.iloc[1,4]]*10
df_rmi_queuelen_s2 = [df_rmi_system_0.iloc[2,4]]*10 + [df_rmi_system_1.iloc[2,4]]*10 + [df_rmi_system_2.iloc[2,4]]*10 + [df_rmi_system_3.iloc[2,4]]*10+ [df_rmi_system_4.iloc[2,4]]*10 + [df_rmi_system_5.iloc[2,4]]*10+ [df_rmi_system_6.iloc[2,4]]*10 + [df_rmi_system_7.iloc[2,4]]*10+ [df_rmi_system_8.iloc[2,4]]*10 + [df_rmi_system_9.iloc[2,4]]*10
df_rmi_queuelen_s3 = [df_rmi_system_0.iloc[3,4]]*10 + [df_rmi_system_1.iloc[3,4]]*10 + [df_rmi_system_2.iloc[3,4]]*10 + [df_rmi_system_3.iloc[3,4]]*10+ [df_rmi_system_4.iloc[3,4]]*10 + [df_rmi_system_5.iloc[3,4]]*10+ [df_rmi_system_6.iloc[3,4]]*10 + [df_rmi_system_7.iloc[3,4]]*10+ [df_rmi_system_8.iloc[3,4]]*10 + [df_rmi_system_9.iloc[3,4]]*10

df_rmi_arriving_s0 = [df_rmi_system_0.iloc[0,1]]*10 + [df_rmi_system_1.iloc[0,1]]*10 + [df_rmi_system_2.iloc[0,1]]*10 + [df_rmi_system_3.iloc[0,1]]*10+ [df_rmi_system_4.iloc[0,1]]*10 + [df_rmi_system_5.iloc[0,1]]*10+ [df_rmi_system_6.iloc[0,1]]*10 + [df_rmi_system_7.iloc[0,1]]*10+ [df_rmi_system_8.iloc[0,1]]*10 + [df_rmi_system_9.iloc[0,1]]*10
df_rmi_arriving_s1 = [df_rmi_system_0.iloc[1,1]]*10 + [df_rmi_system_1.iloc[1,1]]*10 + [df_rmi_system_2.iloc[1,1]]*10 + [df_rmi_system_3.iloc[1,1]]*10+ [df_rmi_system_4.iloc[1,1]]*10 + [df_rmi_system_5.iloc[1,1]]*10+ [df_rmi_system_6.iloc[1,1]]*10 + [df_rmi_system_7.iloc[1,1]]*10+ [df_rmi_system_8.iloc[1,1]]*10 + [df_rmi_system_9.iloc[1,1]]*10
df_rmi_arriving_s2 = [df_rmi_system_0.iloc[2,1]]*10 + [df_rmi_system_1.iloc[2,1]]*10 + [df_rmi_system_2.iloc[2,1]]*10 + [df_rmi_system_3.iloc[2,1]]*10+ [df_rmi_system_4.iloc[2,1]]*10 + [df_rmi_system_5.iloc[2,1]]*10+ [df_rmi_system_6.iloc[2,1]]*10 + [df_rmi_system_7.iloc[2,1]]*10+ [df_rmi_system_8.iloc[2,1]]*10 + [df_rmi_system_9.iloc[2,1]]*10
df_rmi_arriving_s3 = [df_rmi_system_0.iloc[3,1]]*10 + [df_rmi_system_1.iloc[3,1]]*10 + [df_rmi_system_2.iloc[3,1]]*10 + [df_rmi_system_3.iloc[3,1]]*10+ [df_rmi_system_4.iloc[3,1]]*10 + [df_rmi_system_5.iloc[3,1]]*10+ [df_rmi_system_6.iloc[3,1]]*10 + [df_rmi_system_7.iloc[3,1]]*10+ [df_rmi_system_8.iloc[3,1]]*10 + [df_rmi_system_9.iloc[3,1]]*10

# %% [markdown]
# __For shelter 0 metrics__

# %%
#Datasets for abandonment percentage
df_rmi_abandonment_female_s0 = [df_rmi_abandonment_0.iloc[0,1]]*10 + [df_rmi_abandonment_1.iloc[0,1]]*10 + [df_rmi_abandonment_2.iloc[0,1]]*10 + [df_rmi_abandonment_3.iloc[0,1]]*10+ [df_rmi_abandonment_4.iloc[0,1]]*10 + [df_rmi_abandonment_5.iloc[0,1]]*10+ [df_rmi_abandonment_6.iloc[0,1]]*10 + [df_rmi_abandonment_7.iloc[0,1]]*10+ [df_rmi_abandonment_8.iloc[0,1]]*10 + [df_rmi_abandonment_9.iloc[0,1]]*10
df_rmi_abandonment_male_s0 = [df_rmi_abandonment_0.iloc[1,1]]*10 + [df_rmi_abandonment_1.iloc[1,1]]*10 + [df_rmi_abandonment_2.iloc[1,1]]*10 + [df_rmi_abandonment_3.iloc[1,1]]*10+ [df_rmi_abandonment_4.iloc[1,1]]*10 + [df_rmi_abandonment_5.iloc[1,1]]*10+ [df_rmi_abandonment_6.iloc[1,1]]*10 + [df_rmi_abandonment_7.iloc[1,1]]*10+ [df_rmi_abandonment_8.iloc[1,1]]*10 + [df_rmi_abandonment_9.iloc[1,1]]*10
df_rmi_abandonment_noncis_s0 = [df_rmi_abandonment_0.iloc[2,1]]*10 + [df_rmi_abandonment_1.iloc[2,1]]*10 + [df_rmi_abandonment_2.iloc[2,1]]*10 + [df_rmi_abandonment_3.iloc[2,1]]*10+ [df_rmi_abandonment_4.iloc[2,1]]*10 + [df_rmi_abandonment_5.iloc[2,1]]*10+ [df_rmi_abandonment_6.iloc[2,1]]*10 + [df_rmi_abandonment_7.iloc[2,1]]*10+ [df_rmi_abandonment_8.iloc[2,1]]*10 + [df_rmi_abandonment_9.iloc[2,1]]*10

df_rmi_abandonment_older21_s0 = [df_rmi_abandonment_0.iloc[3,1]]*10 + [df_rmi_abandonment_1.iloc[3,1]]*10 + [df_rmi_abandonment_2.iloc[3,1]]*10 + [df_rmi_abandonment_3.iloc[3,1]]*10+ [df_rmi_abandonment_4.iloc[3,1]]*10 + [df_rmi_abandonment_5.iloc[3,1]]*10+ [df_rmi_abandonment_6.iloc[3,1]]*10 + [df_rmi_abandonment_7.iloc[3,1]]*10+ [df_rmi_abandonment_8.iloc[3,1]]*10 + [df_rmi_abandonment_9.iloc[3,1]]*10
df_rmi_abandonment_younger21_s0 = [df_rmi_abandonment_0.iloc[4,1]]*10 + [df_rmi_abandonment_1.iloc[4,1]]*10 + [df_rmi_abandonment_2.iloc[4,1]]*10 + [df_rmi_abandonment_3.iloc[4,1]]*10+ [df_rmi_abandonment_4.iloc[4,1]]*10 + [df_rmi_abandonment_5.iloc[4,1]]*10+ [df_rmi_abandonment_6.iloc[4,1]]*10 + [df_rmi_abandonment_7.iloc[4,1]]*10+ [df_rmi_abandonment_8.iloc[4,1]]*10 + [df_rmi_abandonment_9.iloc[4,1]]*10

df_rmi_abandonment_withchild_s0 = [df_rmi_abandonment_0.iloc[5,1]]*10 + [df_rmi_abandonment_1.iloc[5,1]]*10 + [df_rmi_abandonment_2.iloc[5,1]]*10 + [df_rmi_abandonment_3.iloc[5,1]]*10+ [df_rmi_abandonment_4.iloc[5,1]]*10 + [df_rmi_abandonment_5.iloc[5,1]]*10+ [df_rmi_abandonment_6.iloc[5,1]]*10 + [df_rmi_abandonment_7.iloc[5,1]]*10+ [df_rmi_abandonment_8.iloc[5,1]]*10 + [df_rmi_abandonment_9.iloc[5,1]]*10
df_rmi_abandonment_nochild_s0 = [df_rmi_abandonment_0.iloc[6,1]]*10 + [df_rmi_abandonment_1.iloc[6,1]]*10 + [df_rmi_abandonment_2.iloc[6,1]]*10 + [df_rmi_abandonment_3.iloc[6,1]]*10+ [df_rmi_abandonment_4.iloc[6,1]]*10 + [df_rmi_abandonment_5.iloc[6,1]]*10+ [df_rmi_abandonment_6.iloc[6,1]]*10 + [df_rmi_abandonment_7.iloc[6,1]]*10+ [df_rmi_abandonment_8.iloc[6,1]]*10 + [df_rmi_abandonment_9.iloc[6,1]]*10

df_rmi_abandonment_immigrant_s0 = [df_rmi_abandonment_0.iloc[7,1]]*10 + [df_rmi_abandonment_1.iloc[7,1]]*10 + [df_rmi_abandonment_2.iloc[7,1]]*10 + [df_rmi_abandonment_3.iloc[7,1]]*10+ [df_rmi_abandonment_4.iloc[7,1]]*10 + [df_rmi_abandonment_5.iloc[7,1]]*10+ [df_rmi_abandonment_6.iloc[7,1]]*10 + [df_rmi_abandonment_7.iloc[7,1]]*10+ [df_rmi_abandonment_8.iloc[7,1]]*10 + [df_rmi_abandonment_9.iloc[7,1]]*10
df_rmi_abandonment_notimmigrant_s0 = [df_rmi_abandonment_0.iloc[8,1]]*10 + [df_rmi_abandonment_1.iloc[8,1]]*10 + [df_rmi_abandonment_2.iloc[8,1]]*10 + [df_rmi_abandonment_3.iloc[8,1]]*10+ [df_rmi_abandonment_4.iloc[8,1]]*10 + [df_rmi_abandonment_5.iloc[8,1]]*10+ [df_rmi_abandonment_6.iloc[8,1]]*10 + [df_rmi_abandonment_7.iloc[8,1]]*10+ [df_rmi_abandonment_8.iloc[8,1]]*10 + [df_rmi_abandonment_9.iloc[8,1]]*10

df_rmi_abandonment_htvictim_s0 = [df_rmi_abandonment_0.iloc[9,1]]*10 + [df_rmi_abandonment_1.iloc[9,1]]*10 + [df_rmi_abandonment_2.iloc[9,1]]*10 + [df_rmi_abandonment_3.iloc[9,1]]*10+ [df_rmi_abandonment_4.iloc[9,1]]*10 + [df_rmi_abandonment_5.iloc[9,1]]*10+ [df_rmi_abandonment_6.iloc[9,1]]*10 + [df_rmi_abandonment_7.iloc[9,1]]*10+ [df_rmi_abandonment_8.iloc[9,1]]*10 + [df_rmi_abandonment_9.iloc[9,1]]*10
df_rmi_abandonment_nothtvictim_s0 = [df_rmi_abandonment_0.iloc[10,1]]*10 + [df_rmi_abandonment_1.iloc[10,1]]*10 + [df_rmi_abandonment_2.iloc[10,1]]*10 + [df_rmi_abandonment_3.iloc[10,1]]*10+ [df_rmi_abandonment_4.iloc[10,1]]*10 + [df_rmi_abandonment_5.iloc[10,1]]*10+ [df_rmi_abandonment_6.iloc[10,1]]*10 + [df_rmi_abandonment_7.iloc[10,1]]*10+ [df_rmi_abandonment_8.iloc[10,1]]*10 + [df_rmi_abandonment_9.iloc[10,1]]*10

#Datasets for average wait
df_rmi_wait_female_s0 = [df_rmi_wait_0.iloc[0,1]]*10 + [df_rmi_wait_1.iloc[0,1]]*10 + [df_rmi_wait_2.iloc[0,1]]*10 + [df_rmi_wait_3.iloc[0,1]]*10+ [df_rmi_wait_4.iloc[0,1]]*10 + [df_rmi_wait_5.iloc[0,1]]*10+ [df_rmi_wait_6.iloc[0,1]]*10 + [df_rmi_wait_7.iloc[0,1]]*10+ [df_rmi_wait_8.iloc[0,1]]*10 + [df_rmi_wait_9.iloc[0,1]]*10
df_rmi_wait_male_s0 = [df_rmi_wait_0.iloc[1,1]]*10 + [df_rmi_wait_1.iloc[1,1]]*10 + [df_rmi_wait_2.iloc[1,1]]*10 + [df_rmi_wait_3.iloc[1,1]]*10+ [df_rmi_wait_4.iloc[1,1]]*10 + [df_rmi_wait_5.iloc[1,1]]*10+ [df_rmi_wait_6.iloc[1,1]]*10 + [df_rmi_wait_7.iloc[1,1]]*10+ [df_rmi_wait_8.iloc[1,1]]*10 + [df_rmi_wait_9.iloc[1,1]]*10
df_rmi_wait_noncis_s0 = [df_rmi_wait_0.iloc[2,1]]*10 + [df_rmi_wait_1.iloc[2,1]]*10 + [df_rmi_wait_2.iloc[2,1]]*10 + [df_rmi_wait_3.iloc[2,1]]*10+ [df_rmi_wait_4.iloc[2,1]]*10 + [df_rmi_wait_5.iloc[2,1]]*10+ [df_rmi_wait_6.iloc[2,1]]*10 + [df_rmi_wait_7.iloc[2,1]]*10+ [df_rmi_wait_8.iloc[2,1]]*10 + [df_rmi_wait_9.iloc[2,1]]*10

df_rmi_wait_older21_s0 = [df_rmi_wait_0.iloc[3,1]]*10 + [df_rmi_wait_1.iloc[3,1]]*10 + [df_rmi_wait_2.iloc[3,1]]*10 + [df_rmi_wait_3.iloc[3,1]]*10+ [df_rmi_wait_4.iloc[3,1]]*10 + [df_rmi_wait_5.iloc[3,1]]*10+ [df_rmi_wait_6.iloc[3,1]]*10 + [df_rmi_wait_7.iloc[3,1]]*10+ [df_rmi_wait_8.iloc[3,1]]*10 + [df_rmi_wait_9.iloc[3,1]]*10
df_rmi_wait_younger21_s0 = [df_rmi_wait_0.iloc[4,1]]*10 + [df_rmi_wait_1.iloc[4,1]]*10 + [df_rmi_wait_2.iloc[4,1]]*10 + [df_rmi_wait_3.iloc[4,1]]*10+ [df_rmi_wait_4.iloc[4,1]]*10 + [df_rmi_wait_5.iloc[4,1]]*10+ [df_rmi_wait_6.iloc[4,1]]*10 + [df_rmi_wait_7.iloc[4,1]]*10+ [df_rmi_wait_8.iloc[4,1]]*10 + [df_rmi_wait_9.iloc[4,1]]*10

df_rmi_wait_withchild_s0 = [df_rmi_wait_0.iloc[5,1]]*10 + [df_rmi_wait_1.iloc[5,1]]*10 + [df_rmi_wait_2.iloc[5,1]]*10 + [df_rmi_wait_3.iloc[5,1]]*10+ [df_rmi_wait_4.iloc[5,1]]*10 + [df_rmi_wait_5.iloc[5,1]]*10+ [df_rmi_wait_6.iloc[5,1]]*10 + [df_rmi_wait_7.iloc[5,1]]*10+ [df_rmi_wait_8.iloc[5,1]]*10 + [df_rmi_wait_9.iloc[5,1]]*10
df_rmi_wait_nochild_s0 = [df_rmi_wait_0.iloc[6,1]]*10 + [df_rmi_wait_1.iloc[6,1]]*10 + [df_rmi_wait_2.iloc[6,1]]*10 + [df_rmi_wait_3.iloc[6,1]]*10+ [df_rmi_wait_4.iloc[6,1]]*10 + [df_rmi_wait_5.iloc[6,1]]*10+ [df_rmi_wait_6.iloc[6,1]]*10 + [df_rmi_wait_7.iloc[6,1]]*10+ [df_rmi_wait_8.iloc[6,1]]*10 + [df_rmi_wait_9.iloc[6,1]]*10

df_rmi_wait_immigrant_s0 = [df_rmi_wait_0.iloc[7,1]]*10 + [df_rmi_wait_1.iloc[7,1]]*10 + [df_rmi_wait_2.iloc[7,1]]*10 + [df_rmi_wait_3.iloc[7,1]]*10+ [df_rmi_wait_4.iloc[7,1]]*10 + [df_rmi_wait_5.iloc[7,1]]*10+ [df_rmi_wait_6.iloc[7,1]]*10 + [df_rmi_wait_7.iloc[7,1]]*10+ [df_rmi_wait_8.iloc[7,1]]*10 + [df_rmi_wait_9.iloc[7,1]]*10
df_rmi_wait_notimmigrant_s0 = [df_rmi_wait_0.iloc[8,1]]*10 + [df_rmi_wait_1.iloc[8,1]]*10 + [df_rmi_wait_2.iloc[8,1]]*10 + [df_rmi_wait_3.iloc[8,1]]*10+ [df_rmi_wait_4.iloc[8,1]]*10 + [df_rmi_wait_5.iloc[8,1]]*10+ [df_rmi_wait_6.iloc[8,1]]*10 + [df_rmi_wait_7.iloc[8,1]]*10+ [df_rmi_wait_8.iloc[8,1]]*10 + [df_rmi_wait_9.iloc[8,1]]*10

df_rmi_wait_htvictim_s0 = [df_rmi_wait_0.iloc[9,1]]*10 + [df_rmi_wait_1.iloc[9,1]]*10 + [df_rmi_wait_2.iloc[9,1]]*10 + [df_rmi_wait_3.iloc[9,1]]*10+ [df_rmi_wait_4.iloc[9,1]]*10 + [df_rmi_wait_5.iloc[9,1]]*10+ [df_rmi_wait_6.iloc[9,1]]*10 + [df_rmi_wait_7.iloc[9,1]]*10+ [df_rmi_wait_8.iloc[9,1]]*10 + [df_rmi_wait_9.iloc[9,1]]*10
df_rmi_wait_nothtvictim_s0 = [df_rmi_wait_0.iloc[10,1]]*10 + [df_rmi_wait_1.iloc[10,1]]*10 + [df_rmi_wait_2.iloc[10,1]]*10 + [df_rmi_wait_3.iloc[10,1]]*10+ [df_rmi_wait_4.iloc[10,1]]*10 + [df_rmi_wait_5.iloc[10,1]]*10+ [df_rmi_wait_6.iloc[10,1]]*10 + [df_rmi_wait_7.iloc[10,1]]*10+ [df_rmi_wait_8.iloc[10,1]]*10 + [df_rmi_wait_9.iloc[10,1]]*10

#Datasets for number of youth arriving
df_rmi_arriving_female_s0 = [df_rmi_arriving_0.iloc[0,1]]*10 + [df_rmi_arriving_1.iloc[0,1]]*10 + [df_rmi_arriving_2.iloc[0,1]]*10 + [df_rmi_arriving_3.iloc[0,1]]*10+ [df_rmi_arriving_4.iloc[0,1]]*10 + [df_rmi_arriving_5.iloc[0,1]]*10+ [df_rmi_arriving_6.iloc[0,1]]*10 + [df_rmi_arriving_7.iloc[0,1]]*10+ [df_rmi_arriving_8.iloc[0,1]]*10 + [df_rmi_arriving_9.iloc[0,1]]*10
df_rmi_arriving_male_s0 = [df_rmi_arriving_0.iloc[1,1]]*10 + [df_rmi_arriving_1.iloc[1,1]]*10 + [df_rmi_arriving_2.iloc[1,1]]*10 + [df_rmi_arriving_3.iloc[1,1]]*10+ [df_rmi_arriving_4.iloc[1,1]]*10 + [df_rmi_arriving_5.iloc[1,1]]*10+ [df_rmi_arriving_6.iloc[1,1]]*10 + [df_rmi_arriving_7.iloc[1,1]]*10+ [df_rmi_arriving_8.iloc[1,1]]*10 + [df_rmi_arriving_9.iloc[1,1]]*10
df_rmi_arriving_noncis_s0 = [df_rmi_arriving_0.iloc[2,1]]*10 + [df_rmi_arriving_1.iloc[2,1]]*10 + [df_rmi_arriving_2.iloc[2,1]]*10 + [df_rmi_arriving_3.iloc[2,1]]*10+ [df_rmi_arriving_4.iloc[2,1]]*10 + [df_rmi_arriving_5.iloc[2,1]]*10+ [df_rmi_arriving_6.iloc[2,1]]*10 + [df_rmi_arriving_7.iloc[2,1]]*10+ [df_rmi_arriving_8.iloc[2,1]]*10 + [df_rmi_arriving_9.iloc[2,1]]*10

df_rmi_arriving_older21_s0 = [df_rmi_arriving_0.iloc[3,1]]*10 + [df_rmi_arriving_1.iloc[3,1]]*10 + [df_rmi_arriving_2.iloc[3,1]]*10 + [df_rmi_arriving_3.iloc[3,1]]*10+ [df_rmi_arriving_4.iloc[3,1]]*10 + [df_rmi_arriving_5.iloc[3,1]]*10+ [df_rmi_arriving_6.iloc[3,1]]*10 + [df_rmi_arriving_7.iloc[3,1]]*10+ [df_rmi_arriving_8.iloc[3,1]]*10 + [df_rmi_arriving_9.iloc[3,1]]*10
df_rmi_arriving_younger21_s0 = [df_rmi_arriving_0.iloc[4,1]]*10 + [df_rmi_arriving_1.iloc[4,1]]*10 + [df_rmi_arriving_2.iloc[4,1]]*10 + [df_rmi_arriving_3.iloc[4,1]]*10+ [df_rmi_arriving_4.iloc[4,1]]*10 + [df_rmi_arriving_5.iloc[4,1]]*10+ [df_rmi_arriving_6.iloc[4,1]]*10 + [df_rmi_arriving_7.iloc[4,1]]*10+ [df_rmi_arriving_8.iloc[4,1]]*10 + [df_rmi_arriving_9.iloc[4,1]]*10

df_rmi_arriving_withchild_s0 = [df_rmi_arriving_0.iloc[5,1]]*10 + [df_rmi_arriving_1.iloc[5,1]]*10 + [df_rmi_arriving_2.iloc[5,1]]*10 + [df_rmi_arriving_3.iloc[5,1]]*10+ [df_rmi_arriving_4.iloc[5,1]]*10 + [df_rmi_arriving_5.iloc[5,1]]*10+ [df_rmi_arriving_6.iloc[5,1]]*10 + [df_rmi_arriving_7.iloc[5,1]]*10+ [df_rmi_arriving_8.iloc[5,1]]*10 + [df_rmi_arriving_9.iloc[5,1]]*10
df_rmi_arriving_nochild_s0 = [df_rmi_arriving_0.iloc[6,1]]*10 + [df_rmi_arriving_1.iloc[6,1]]*10 + [df_rmi_arriving_2.iloc[6,1]]*10 + [df_rmi_arriving_3.iloc[6,1]]*10+ [df_rmi_arriving_4.iloc[6,1]]*10 + [df_rmi_arriving_5.iloc[6,1]]*10+ [df_rmi_arriving_6.iloc[6,1]]*10 + [df_rmi_arriving_7.iloc[6,1]]*10+ [df_rmi_arriving_8.iloc[6,1]]*10 + [df_rmi_arriving_9.iloc[6,1]]*10

df_rmi_arriving_immigran_s0t = [df_rmi_arriving_0.iloc[7,1]]*10 + [df_rmi_arriving_1.iloc[7,1]]*10 + [df_rmi_arriving_2.iloc[7,1]]*10 + [df_rmi_arriving_3.iloc[7,1]]*10+ [df_rmi_arriving_4.iloc[7,1]]*10 + [df_rmi_arriving_5.iloc[7,1]]*10+ [df_rmi_arriving_6.iloc[7,1]]*10 + [df_rmi_arriving_7.iloc[7,1]]*10+ [df_rmi_arriving_8.iloc[7,1]]*10 + [df_rmi_arriving_9.iloc[7,1]]*10
df_rmi_arriving_notimmigrant_s0 = [df_rmi_arriving_0.iloc[8,1]]*10 + [df_rmi_arriving_1.iloc[8,1]]*10 + [df_rmi_arriving_2.iloc[8,1]]*10 + [df_rmi_arriving_3.iloc[8,1]]*10+ [df_rmi_arriving_4.iloc[8,1]]*10 + [df_rmi_arriving_5.iloc[8,1]]*10+ [df_rmi_arriving_6.iloc[8,1]]*10 + [df_rmi_arriving_7.iloc[8,1]]*10+ [df_rmi_arriving_8.iloc[8,1]]*10 + [df_rmi_arriving_9.iloc[8,1]]*10

df_rmi_arriving_htvictim_s0 = [df_rmi_arriving_0.iloc[9,1]]*10 + [df_rmi_arriving_1.iloc[9,1]]*10 + [df_rmi_arriving_2.iloc[9,1]]*10 + [df_rmi_arriving_3.iloc[9,1]]*10+ [df_rmi_arriving_4.iloc[9,1]]*10 + [df_rmi_arriving_5.iloc[9,1]]*10+ [df_rmi_arriving_6.iloc[9,1]]*10 + [df_rmi_arriving_7.iloc[9,1]]*10+ [df_rmi_arriving_8.iloc[9,1]]*10 + [df_rmi_arriving_9.iloc[9,1]]*10
df_rmi_arriving_nothtvictim_s0 = [df_rmi_arriving_0.iloc[10,1]]*10 + [df_rmi_arriving_1.iloc[10,1]]*10 + [df_rmi_arriving_2.iloc[10,1]]*10 + [df_rmi_arriving_3.iloc[10,1]]*10+ [df_rmi_arriving_4.iloc[10,1]]*10 + [df_rmi_arriving_5.iloc[10,1]]*10+ [df_rmi_arriving_6.iloc[10,1]]*10 + [df_rmi_arriving_7.iloc[10,1]]*10+ [df_rmi_arriving_8.iloc[10,1]]*10 + [df_rmi_arriving_9.iloc[10,1]]*10

# %% [markdown]
# __For shelter 1 metrics__

# %%
#Datasets for abandonment percentage
df_rmi_abandonment_female_s1 = [df_rmi_abandonment_0.iloc[0,2]]*10 + [df_rmi_abandonment_1.iloc[0,2]]*10 + [df_rmi_abandonment_2.iloc[0,2]]*10 + [df_rmi_abandonment_3.iloc[0,2]]*10+ [df_rmi_abandonment_4.iloc[0,2]]*10 + [df_rmi_abandonment_5.iloc[0,2]]*10+ [df_rmi_abandonment_6.iloc[0,2]]*10 + [df_rmi_abandonment_7.iloc[0,2]]*10+ [df_rmi_abandonment_8.iloc[0,2]]*10 + [df_rmi_abandonment_9.iloc[0,2]]*10
df_rmi_abandonment_male_s1 = [df_rmi_abandonment_0.iloc[1,2]]*10 + [df_rmi_abandonment_1.iloc[1,2]]*10 + [df_rmi_abandonment_2.iloc[1,2]]*10 + [df_rmi_abandonment_3.iloc[1,2]]*10+ [df_rmi_abandonment_4.iloc[1,2]]*10 + [df_rmi_abandonment_5.iloc[1,2]]*10+ [df_rmi_abandonment_6.iloc[1,2]]*10 + [df_rmi_abandonment_7.iloc[1,2]]*10+ [df_rmi_abandonment_8.iloc[1,2]]*10 + [df_rmi_abandonment_9.iloc[1,2]]*10
df_rmi_abandonment_noncis_s1 = [df_rmi_abandonment_0.iloc[2,2]]*10 + [df_rmi_abandonment_1.iloc[2,2]]*10 + [df_rmi_abandonment_2.iloc[2,2]]*10 + [df_rmi_abandonment_3.iloc[2,2]]*10+ [df_rmi_abandonment_4.iloc[2,2]]*10 + [df_rmi_abandonment_5.iloc[2,2]]*10+ [df_rmi_abandonment_6.iloc[2,2]]*10 + [df_rmi_abandonment_7.iloc[2,2]]*10+ [df_rmi_abandonment_8.iloc[2,2]]*10 + [df_rmi_abandonment_9.iloc[2,2]]*10

df_rmi_abandonment_older21_s1 = [df_rmi_abandonment_0.iloc[3,2]]*10 + [df_rmi_abandonment_1.iloc[3,2]]*10 + [df_rmi_abandonment_2.iloc[3,2]]*10 + [df_rmi_abandonment_3.iloc[3,2]]*10+ [df_rmi_abandonment_4.iloc[3,2]]*10 + [df_rmi_abandonment_5.iloc[3,2]]*10+ [df_rmi_abandonment_6.iloc[3,2]]*10 + [df_rmi_abandonment_7.iloc[3,2]]*10+ [df_rmi_abandonment_8.iloc[3,2]]*10 + [df_rmi_abandonment_9.iloc[3,2]]*10
df_rmi_abandonment_younger21_s1 = [df_rmi_abandonment_0.iloc[4,2]]*10 + [df_rmi_abandonment_1.iloc[4,2]]*10 + [df_rmi_abandonment_2.iloc[4,2]]*10 + [df_rmi_abandonment_3.iloc[4,2]]*10+ [df_rmi_abandonment_4.iloc[4,2]]*10 + [df_rmi_abandonment_5.iloc[4,2]]*10+ [df_rmi_abandonment_6.iloc[4,2]]*10 + [df_rmi_abandonment_7.iloc[4,2]]*10+ [df_rmi_abandonment_8.iloc[4,2]]*10 + [df_rmi_abandonment_9.iloc[4,2]]*10

df_rmi_abandonment_withchild_s1 = [df_rmi_abandonment_0.iloc[5,2]]*10 + [df_rmi_abandonment_1.iloc[5,2]]*10 + [df_rmi_abandonment_2.iloc[5,2]]*10 + [df_rmi_abandonment_3.iloc[5,2]]*10+ [df_rmi_abandonment_4.iloc[5,2]]*10 + [df_rmi_abandonment_5.iloc[5,2]]*10+ [df_rmi_abandonment_6.iloc[5,2]]*10 + [df_rmi_abandonment_7.iloc[5,2]]*10+ [df_rmi_abandonment_8.iloc[5,2]]*10 + [df_rmi_abandonment_9.iloc[5,2]]*10
df_rmi_abandonment_nochild_s1 = [df_rmi_abandonment_0.iloc[6,2]]*10 + [df_rmi_abandonment_1.iloc[6,2]]*10 + [df_rmi_abandonment_2.iloc[6,2]]*10 + [df_rmi_abandonment_3.iloc[6,2]]*10+ [df_rmi_abandonment_4.iloc[6,2]]*10 + [df_rmi_abandonment_5.iloc[6,2]]*10+ [df_rmi_abandonment_6.iloc[6,2]]*10 + [df_rmi_abandonment_7.iloc[6,2]]*10+ [df_rmi_abandonment_8.iloc[6,2]]*10 + [df_rmi_abandonment_9.iloc[6,2]]*10

df_rmi_abandonment_immigrant_s1 = [df_rmi_abandonment_0.iloc[7,2]]*10 + [df_rmi_abandonment_1.iloc[7,2]]*10 + [df_rmi_abandonment_2.iloc[7,2]]*10 + [df_rmi_abandonment_3.iloc[7,2]]*10+ [df_rmi_abandonment_4.iloc[7,2]]*10 + [df_rmi_abandonment_5.iloc[7,2]]*10+ [df_rmi_abandonment_6.iloc[7,2]]*10 + [df_rmi_abandonment_7.iloc[7,2]]*10+ [df_rmi_abandonment_8.iloc[7,2]]*10 + [df_rmi_abandonment_9.iloc[7,2]]*10
df_rmi_abandonment_notimmigrant_s1 = [df_rmi_abandonment_0.iloc[8,2]]*10 + [df_rmi_abandonment_1.iloc[8,2]]*10 + [df_rmi_abandonment_2.iloc[8,2]]*10 + [df_rmi_abandonment_3.iloc[8,2]]*10+ [df_rmi_abandonment_4.iloc[8,2]]*10 + [df_rmi_abandonment_5.iloc[8,2]]*10+ [df_rmi_abandonment_6.iloc[8,2]]*10 + [df_rmi_abandonment_7.iloc[8,2]]*10+ [df_rmi_abandonment_8.iloc[8,2]]*10 + [df_rmi_abandonment_9.iloc[8,2]]*10

df_rmi_abandonment_htvictim_s1 = [df_rmi_abandonment_0.iloc[9,2]]*10 + [df_rmi_abandonment_1.iloc[9,2]]*10 + [df_rmi_abandonment_2.iloc[9,2]]*10 + [df_rmi_abandonment_3.iloc[9,2]]*10+ [df_rmi_abandonment_4.iloc[9,2]]*10 + [df_rmi_abandonment_5.iloc[9,2]]*10+ [df_rmi_abandonment_6.iloc[9,2]]*10 + [df_rmi_abandonment_7.iloc[9,2]]*10+ [df_rmi_abandonment_8.iloc[9,2]]*10 + [df_rmi_abandonment_9.iloc[9,2]]*10
df_rmi_abandonment_nothtvictim_s1 = [df_rmi_abandonment_0.iloc[10,2]]*10 + [df_rmi_abandonment_1.iloc[10,2]]*10 + [df_rmi_abandonment_2.iloc[10,2]]*10 + [df_rmi_abandonment_3.iloc[10,2]]*10+ [df_rmi_abandonment_4.iloc[10,2]]*10 + [df_rmi_abandonment_5.iloc[10,2]]*10+ [df_rmi_abandonment_6.iloc[10,2]]*10 + [df_rmi_abandonment_7.iloc[10,2]]*10+ [df_rmi_abandonment_8.iloc[10,2]]*10 + [df_rmi_abandonment_9.iloc[10,2]]*10

#Datasets for average wait
df_rmi_wait_female_s1 = [df_rmi_wait_0.iloc[0,2]]*10 + [df_rmi_wait_1.iloc[0,2]]*10 + [df_rmi_wait_2.iloc[0,2]]*10 + [df_rmi_wait_3.iloc[0,2]]*10+ [df_rmi_wait_4.iloc[0,2]]*10 + [df_rmi_wait_5.iloc[0,2]]*10+ [df_rmi_wait_6.iloc[0,2]]*10 + [df_rmi_wait_7.iloc[0,2]]*10+ [df_rmi_wait_8.iloc[0,2]]*10 + [df_rmi_wait_9.iloc[0,2]]*10
df_rmi_wait_male_s1 = [df_rmi_wait_0.iloc[1,2]]*10 + [df_rmi_wait_1.iloc[1,2]]*10 + [df_rmi_wait_2.iloc[1,2]]*10 + [df_rmi_wait_3.iloc[1,2]]*10+ [df_rmi_wait_4.iloc[1,2]]*10 + [df_rmi_wait_5.iloc[1,2]]*10+ [df_rmi_wait_6.iloc[1,2]]*10 + [df_rmi_wait_7.iloc[1,2]]*10+ [df_rmi_wait_8.iloc[1,2]]*10 + [df_rmi_wait_9.iloc[1,2]]*10
df_rmi_wait_noncis_s1 = [df_rmi_wait_0.iloc[2,2]]*10 + [df_rmi_wait_1.iloc[2,2]]*10 + [df_rmi_wait_2.iloc[2,2]]*10 + [df_rmi_wait_3.iloc[2,2]]*10+ [df_rmi_wait_4.iloc[2,2]]*10 + [df_rmi_wait_5.iloc[2,2]]*10+ [df_rmi_wait_6.iloc[2,2]]*10 + [df_rmi_wait_7.iloc[2,2]]*10+ [df_rmi_wait_8.iloc[2,2]]*10 + [df_rmi_wait_9.iloc[2,2]]*10

df_rmi_wait_older21_s1 = [df_rmi_wait_0.iloc[3,2]]*10 + [df_rmi_wait_1.iloc[3,2]]*10 + [df_rmi_wait_2.iloc[3,2]]*10 + [df_rmi_wait_3.iloc[3,2]]*10+ [df_rmi_wait_4.iloc[3,2]]*10 + [df_rmi_wait_5.iloc[3,2]]*10+ [df_rmi_wait_6.iloc[3,2]]*10 + [df_rmi_wait_7.iloc[3,2]]*10+ [df_rmi_wait_8.iloc[3,2]]*10 + [df_rmi_wait_9.iloc[3,2]]*10
df_rmi_wait_younger21_s1 = [df_rmi_wait_0.iloc[4,2]]*10 + [df_rmi_wait_1.iloc[4,2]]*10 + [df_rmi_wait_2.iloc[4,2]]*10 + [df_rmi_wait_3.iloc[4,2]]*10+ [df_rmi_wait_4.iloc[4,2]]*10 + [df_rmi_wait_5.iloc[4,2]]*10+ [df_rmi_wait_6.iloc[4,2]]*10 + [df_rmi_wait_7.iloc[4,2]]*10+ [df_rmi_wait_8.iloc[4,2]]*10 + [df_rmi_wait_9.iloc[4,2]]*10

df_rmi_wait_withchild_s1 = [df_rmi_wait_0.iloc[5,2]]*10 + [df_rmi_wait_1.iloc[5,2]]*10 + [df_rmi_wait_2.iloc[5,2]]*10 + [df_rmi_wait_3.iloc[5,2]]*10+ [df_rmi_wait_4.iloc[5,2]]*10 + [df_rmi_wait_5.iloc[5,2]]*10+ [df_rmi_wait_6.iloc[5,2]]*10 + [df_rmi_wait_7.iloc[5,2]]*10+ [df_rmi_wait_8.iloc[5,2]]*10 + [df_rmi_wait_9.iloc[5,2]]*10
df_rmi_wait_nochild_s1 = [df_rmi_wait_0.iloc[6,2]]*10 + [df_rmi_wait_1.iloc[6,2]]*10 + [df_rmi_wait_2.iloc[6,2]]*10 + [df_rmi_wait_3.iloc[6,2]]*10+ [df_rmi_wait_4.iloc[6,2]]*10 + [df_rmi_wait_5.iloc[6,2]]*10+ [df_rmi_wait_6.iloc[6,2]]*10 + [df_rmi_wait_7.iloc[6,2]]*10+ [df_rmi_wait_8.iloc[6,2]]*10 + [df_rmi_wait_9.iloc[6,2]]*10

df_rmi_wait_immigrant_s1 = [df_rmi_wait_0.iloc[7,2]]*10 + [df_rmi_wait_1.iloc[7,2]]*10 + [df_rmi_wait_2.iloc[7,2]]*10 + [df_rmi_wait_3.iloc[7,2]]*10+ [df_rmi_wait_4.iloc[7,2]]*10 + [df_rmi_wait_5.iloc[7,2]]*10+ [df_rmi_wait_6.iloc[7,2]]*10 + [df_rmi_wait_7.iloc[7,2]]*10+ [df_rmi_wait_8.iloc[7,2]]*10 + [df_rmi_wait_9.iloc[7,2]]*10
df_rmi_wait_notimmigrant_s1 = [df_rmi_wait_0.iloc[8,2]]*10 + [df_rmi_wait_1.iloc[8,2]]*10 + [df_rmi_wait_2.iloc[8,2]]*10 + [df_rmi_wait_3.iloc[8,2]]*10+ [df_rmi_wait_4.iloc[8,2]]*10 + [df_rmi_wait_5.iloc[8,2]]*10+ [df_rmi_wait_6.iloc[8,2]]*10 + [df_rmi_wait_7.iloc[8,2]]*10+ [df_rmi_wait_8.iloc[8,2]]*10 + [df_rmi_wait_9.iloc[8,2]]*10

df_rmi_wait_htvictim_s1 = [df_rmi_wait_0.iloc[9,2]]*10 + [df_rmi_wait_1.iloc[9,2]]*10 + [df_rmi_wait_2.iloc[9,2]]*10 + [df_rmi_wait_3.iloc[9,2]]*10+ [df_rmi_wait_4.iloc[9,2]]*10 + [df_rmi_wait_5.iloc[9,2]]*10+ [df_rmi_wait_6.iloc[9,2]]*10 + [df_rmi_wait_7.iloc[9,2]]*10+ [df_rmi_wait_8.iloc[9,2]]*10 + [df_rmi_wait_9.iloc[9,2]]*10
df_rmi_wait_nothtvictim_s1 = [df_rmi_wait_0.iloc[10,2]]*10 + [df_rmi_wait_1.iloc[10,2]]*10 + [df_rmi_wait_2.iloc[10,2]]*10 + [df_rmi_wait_3.iloc[10,2]]*10+ [df_rmi_wait_4.iloc[10,2]]*10 + [df_rmi_wait_5.iloc[10,2]]*10+ [df_rmi_wait_6.iloc[10,2]]*10 + [df_rmi_wait_7.iloc[10,2]]*10+ [df_rmi_wait_8.iloc[10,2]]*10 + [df_rmi_wait_9.iloc[10,2]]*10

#Datasets for number of youth arriving
df_rmi_arriving_female = [df_rmi_arriving_0.iloc[0,2]]*10 + [df_rmi_arriving_1.iloc[0,2]]*10 + [df_rmi_arriving_2.iloc[0,2]]*10 + [df_rmi_arriving_3.iloc[0,2]]*10+ [df_rmi_arriving_4.iloc[0,2]]*10 + [df_rmi_arriving_5.iloc[0,2]]*10+ [df_rmi_arriving_6.iloc[0,2]]*10 + [df_rmi_arriving_7.iloc[0,2]]*10+ [df_rmi_arriving_8.iloc[0,2]]*10 + [df_rmi_arriving_9.iloc[0,2]]*10
df_rmi_arriving_male_s1 = [df_rmi_arriving_0.iloc[1,2]]*10 + [df_rmi_arriving_1.iloc[1,2]]*10 + [df_rmi_arriving_2.iloc[1,2]]*10 + [df_rmi_arriving_3.iloc[1,2]]*10+ [df_rmi_arriving_4.iloc[1,2]]*10 + [df_rmi_arriving_5.iloc[1,2]]*10+ [df_rmi_arriving_6.iloc[1,2]]*10 + [df_rmi_arriving_7.iloc[1,2]]*10+ [df_rmi_arriving_8.iloc[1,2]]*10 + [df_rmi_arriving_9.iloc[1,2]]*10
df_rmi_arriving_noncis_s1 = [df_rmi_arriving_0.iloc[2,2]]*10 + [df_rmi_arriving_1.iloc[2,2]]*10 + [df_rmi_arriving_2.iloc[2,2]]*10 + [df_rmi_arriving_3.iloc[2,2]]*10+ [df_rmi_arriving_4.iloc[2,2]]*10 + [df_rmi_arriving_5.iloc[2,2]]*10+ [df_rmi_arriving_6.iloc[2,2]]*10 + [df_rmi_arriving_7.iloc[2,2]]*10+ [df_rmi_arriving_8.iloc[2,2]]*10 + [df_rmi_arriving_9.iloc[2,2]]*10

df_rmi_arriving_older21_s1 = [df_rmi_arriving_0.iloc[3,2]]*10 + [df_rmi_arriving_1.iloc[3,2]]*10 + [df_rmi_arriving_2.iloc[3,2]]*10 + [df_rmi_arriving_3.iloc[3,2]]*10+ [df_rmi_arriving_4.iloc[3,2]]*10 + [df_rmi_arriving_5.iloc[3,2]]*10+ [df_rmi_arriving_6.iloc[3,2]]*10 + [df_rmi_arriving_7.iloc[3,2]]*10+ [df_rmi_arriving_8.iloc[3,2]]*10 + [df_rmi_arriving_9.iloc[3,2]]*10
df_rmi_arriving_younger21_s1 = [df_rmi_arriving_0.iloc[4,2]]*10 + [df_rmi_arriving_1.iloc[4,2]]*10 + [df_rmi_arriving_2.iloc[4,2]]*10 + [df_rmi_arriving_3.iloc[4,2]]*10+ [df_rmi_arriving_4.iloc[4,2]]*10 + [df_rmi_arriving_5.iloc[4,2]]*10+ [df_rmi_arriving_6.iloc[4,2]]*10 + [df_rmi_arriving_7.iloc[4,2]]*10+ [df_rmi_arriving_8.iloc[4,2]]*10 + [df_rmi_arriving_9.iloc[4,2]]*10

df_rmi_arriving_withchild_s1 = [df_rmi_arriving_0.iloc[5,2]]*10 + [df_rmi_arriving_1.iloc[5,2]]*10 + [df_rmi_arriving_2.iloc[5,2]]*10 + [df_rmi_arriving_3.iloc[5,2]]*10+ [df_rmi_arriving_4.iloc[5,2]]*10 + [df_rmi_arriving_5.iloc[5,2]]*10+ [df_rmi_arriving_6.iloc[5,2]]*10 + [df_rmi_arriving_7.iloc[5,2]]*10+ [df_rmi_arriving_8.iloc[5,2]]*10 + [df_rmi_arriving_9.iloc[5,2]]*10
df_rmi_arriving_nochild_s1 = [df_rmi_arriving_0.iloc[6,2]]*10 + [df_rmi_arriving_1.iloc[6,2]]*10 + [df_rmi_arriving_2.iloc[6,2]]*10 + [df_rmi_arriving_3.iloc[6,2]]*10+ [df_rmi_arriving_4.iloc[6,2]]*10 + [df_rmi_arriving_5.iloc[6,2]]*10+ [df_rmi_arriving_6.iloc[6,2]]*10 + [df_rmi_arriving_7.iloc[6,2]]*10+ [df_rmi_arriving_8.iloc[6,2]]*10 + [df_rmi_arriving_9.iloc[6,2]]*10

df_rmi_arriving_immigrant_s1 = [df_rmi_arriving_0.iloc[7,2]]*10 + [df_rmi_arriving_1.iloc[7,2]]*10 + [df_rmi_arriving_2.iloc[7,2]]*10 + [df_rmi_arriving_3.iloc[7,2]]*10+ [df_rmi_arriving_4.iloc[7,2]]*10 + [df_rmi_arriving_5.iloc[7,2]]*10+ [df_rmi_arriving_6.iloc[7,2]]*10 + [df_rmi_arriving_7.iloc[7,2]]*10+ [df_rmi_arriving_8.iloc[7,2]]*10 + [df_rmi_arriving_9.iloc[7,2]]*10
df_rmi_arriving_notimmigrant_s1 = [df_rmi_arriving_0.iloc[8,2]]*10 + [df_rmi_arriving_1.iloc[8,2]]*10 + [df_rmi_arriving_2.iloc[8,2]]*10 + [df_rmi_arriving_3.iloc[8,2]]*10+ [df_rmi_arriving_4.iloc[8,2]]*10 + [df_rmi_arriving_5.iloc[8,2]]*10+ [df_rmi_arriving_6.iloc[8,2]]*10 + [df_rmi_arriving_7.iloc[8,2]]*10+ [df_rmi_arriving_8.iloc[8,2]]*10 + [df_rmi_arriving_9.iloc[8,2]]*10

df_rmi_arriving_htvictim_s1 = [df_rmi_arriving_0.iloc[9,2]]*10 + [df_rmi_arriving_1.iloc[9,2]]*10 + [df_rmi_arriving_2.iloc[9,2]]*10 + [df_rmi_arriving_3.iloc[9,2]]*10+ [df_rmi_arriving_4.iloc[9,2]]*10 + [df_rmi_arriving_5.iloc[9,2]]*10+ [df_rmi_arriving_6.iloc[9,2]]*10 + [df_rmi_arriving_7.iloc[9,2]]*10+ [df_rmi_arriving_8.iloc[9,2]]*10 + [df_rmi_arriving_9.iloc[9,2]]*10
df_rmi_arriving_nothtvictim_s1 = [df_rmi_arriving_0.iloc[10,2]]*10 + [df_rmi_arriving_1.iloc[10,2]]*10 + [df_rmi_arriving_2.iloc[10,2]]*10 + [df_rmi_arriving_3.iloc[10,2]]*10+ [df_rmi_arriving_4.iloc[10,2]]*10 + [df_rmi_arriving_5.iloc[10,2]]*10+ [df_rmi_arriving_6.iloc[10,2]]*10 + [df_rmi_arriving_7.iloc[10,2]]*10+ [df_rmi_arriving_8.iloc[10,2]]*10 + [df_rmi_arriving_9.iloc[10,2]]*10

# %% [markdown]
# __For shelter 2 metrics__

# %%
#Datasets for abandonment percentage
df_rmi_abandonment_female_s2 = [df_rmi_abandonment_0.iloc[0,3]]*10 + [df_rmi_abandonment_1.iloc[0,3]]*10 + [df_rmi_abandonment_2.iloc[0,3]]*10 + [df_rmi_abandonment_3.iloc[0,3]]*10+ [df_rmi_abandonment_4.iloc[0,3]]*10 + [df_rmi_abandonment_5.iloc[0,3]]*10+ [df_rmi_abandonment_6.iloc[0,3]]*10 + [df_rmi_abandonment_7.iloc[0,3]]*10+ [df_rmi_abandonment_8.iloc[0,3]]*10 + [df_rmi_abandonment_9.iloc[0,3]]*10
df_rmi_abandonment_male_s2 = [df_rmi_abandonment_0.iloc[1,3]]*10 + [df_rmi_abandonment_1.iloc[1,3]]*10 + [df_rmi_abandonment_2.iloc[1,3]]*10 + [df_rmi_abandonment_3.iloc[1,3]]*10+ [df_rmi_abandonment_4.iloc[1,3]]*10 + [df_rmi_abandonment_5.iloc[1,3]]*10+ [df_rmi_abandonment_6.iloc[1,3]]*10 + [df_rmi_abandonment_7.iloc[1,3]]*10+ [df_rmi_abandonment_8.iloc[1,3]]*10 + [df_rmi_abandonment_9.iloc[1,3]]*10
df_rmi_abandonment_noncis_s2 = [df_rmi_abandonment_0.iloc[2,3]]*10 + [df_rmi_abandonment_1.iloc[2,3]]*10 + [df_rmi_abandonment_2.iloc[2,3]]*10 + [df_rmi_abandonment_3.iloc[2,3]]*10+ [df_rmi_abandonment_4.iloc[2,3]]*10 + [df_rmi_abandonment_5.iloc[2,3]]*10+ [df_rmi_abandonment_6.iloc[2,3]]*10 + [df_rmi_abandonment_7.iloc[2,3]]*10+ [df_rmi_abandonment_8.iloc[2,3]]*10 + [df_rmi_abandonment_9.iloc[2,3]]*10

df_rmi_abandonment_older21_s2 = [df_rmi_abandonment_0.iloc[3,3]]*10 + [df_rmi_abandonment_1.iloc[3,3]]*10 + [df_rmi_abandonment_2.iloc[3,3]]*10 + [df_rmi_abandonment_3.iloc[3,3]]*10+ [df_rmi_abandonment_4.iloc[3,3]]*10 + [df_rmi_abandonment_5.iloc[3,3]]*10+ [df_rmi_abandonment_6.iloc[3,3]]*10 + [df_rmi_abandonment_7.iloc[3,3]]*10+ [df_rmi_abandonment_8.iloc[3,3]]*10 + [df_rmi_abandonment_9.iloc[3,3]]*10
df_rmi_abandonment_younger21_s2 = [df_rmi_abandonment_0.iloc[4,3]]*10 + [df_rmi_abandonment_1.iloc[4,3]]*10 + [df_rmi_abandonment_2.iloc[4,3]]*10 + [df_rmi_abandonment_3.iloc[4,3]]*10+ [df_rmi_abandonment_4.iloc[4,3]]*10 + [df_rmi_abandonment_5.iloc[4,3]]*10+ [df_rmi_abandonment_6.iloc[4,3]]*10 + [df_rmi_abandonment_7.iloc[4,3]]*10+ [df_rmi_abandonment_8.iloc[4,3]]*10 + [df_rmi_abandonment_9.iloc[4,3]]*10

df_rmi_abandonment_withchild_s2 = [df_rmi_abandonment_0.iloc[5,3]]*10 + [df_rmi_abandonment_1.iloc[5,3]]*10 + [df_rmi_abandonment_2.iloc[5,3]]*10 + [df_rmi_abandonment_3.iloc[5,3]]*10+ [df_rmi_abandonment_4.iloc[5,3]]*10 + [df_rmi_abandonment_5.iloc[5,3]]*10+ [df_rmi_abandonment_6.iloc[5,3]]*10 + [df_rmi_abandonment_7.iloc[5,3]]*10+ [df_rmi_abandonment_8.iloc[5,3]]*10 + [df_rmi_abandonment_9.iloc[5,3]]*10
df_rmi_abandonment_nochild_s2 = [df_rmi_abandonment_0.iloc[6,3]]*10 + [df_rmi_abandonment_1.iloc[6,3]]*10 + [df_rmi_abandonment_2.iloc[6,3]]*10 + [df_rmi_abandonment_3.iloc[6,3]]*10+ [df_rmi_abandonment_4.iloc[6,3]]*10 + [df_rmi_abandonment_5.iloc[6,3]]*10+ [df_rmi_abandonment_6.iloc[6,3]]*10 + [df_rmi_abandonment_7.iloc[6,3]]*10+ [df_rmi_abandonment_8.iloc[6,3]]*10 + [df_rmi_abandonment_9.iloc[6,3]]*10

df_rmi_abandonment_immigrant_s2 = [df_rmi_abandonment_0.iloc[7,3]]*10 + [df_rmi_abandonment_1.iloc[7,3]]*10 + [df_rmi_abandonment_2.iloc[7,3]]*10 + [df_rmi_abandonment_3.iloc[7,3]]*10+ [df_rmi_abandonment_4.iloc[7,3]]*10 + [df_rmi_abandonment_5.iloc[7,3]]*10+ [df_rmi_abandonment_6.iloc[7,3]]*10 + [df_rmi_abandonment_7.iloc[7,3]]*10+ [df_rmi_abandonment_8.iloc[7,3]]*10 + [df_rmi_abandonment_9.iloc[7,3]]*10
df_rmi_abandonment_notimmigrant_s2 = [df_rmi_abandonment_0.iloc[8,3]]*10 + [df_rmi_abandonment_1.iloc[8,3]]*10 + [df_rmi_abandonment_2.iloc[8,3]]*10 + [df_rmi_abandonment_3.iloc[8,3]]*10+ [df_rmi_abandonment_4.iloc[8,3]]*10 + [df_rmi_abandonment_5.iloc[8,3]]*10+ [df_rmi_abandonment_6.iloc[8,3]]*10 + [df_rmi_abandonment_7.iloc[8,3]]*10+ [df_rmi_abandonment_8.iloc[8,3]]*10 + [df_rmi_abandonment_9.iloc[8,3]]*10

df_rmi_abandonment_htvictim_s2 = [df_rmi_abandonment_0.iloc[9,3]]*10 + [df_rmi_abandonment_1.iloc[9,3]]*10 + [df_rmi_abandonment_2.iloc[9,3]]*10 + [df_rmi_abandonment_3.iloc[9,3]]*10+ [df_rmi_abandonment_4.iloc[9,3]]*10 + [df_rmi_abandonment_5.iloc[9,3]]*10+ [df_rmi_abandonment_6.iloc[9,3]]*10 + [df_rmi_abandonment_7.iloc[9,3]]*10+ [df_rmi_abandonment_8.iloc[9,3]]*10 + [df_rmi_abandonment_9.iloc[9,3]]*10
df_rmi_abandonment_nothtvictim_s2 = [df_rmi_abandonment_0.iloc[10,3]]*10 + [df_rmi_abandonment_1.iloc[10,3]]*10 + [df_rmi_abandonment_2.iloc[10,3]]*10 + [df_rmi_abandonment_3.iloc[10,3]]*10+ [df_rmi_abandonment_4.iloc[10,3]]*10 + [df_rmi_abandonment_5.iloc[10,3]]*10+ [df_rmi_abandonment_6.iloc[10,3]]*10 + [df_rmi_abandonment_7.iloc[10,3]]*10+ [df_rmi_abandonment_8.iloc[10,3]]*10 + [df_rmi_abandonment_9.iloc[10,3]]*10

#Datasets for average wait
df_rmi_wait_female_s2 = [df_rmi_wait_0.iloc[0,3]]*10 + [df_rmi_wait_1.iloc[0,3]]*10 + [df_rmi_wait_2.iloc[0,3]]*10 + [df_rmi_wait_3.iloc[0,3]]*10+ [df_rmi_wait_4.iloc[0,3]]*10 + [df_rmi_wait_5.iloc[0,3]]*10+ [df_rmi_wait_6.iloc[0,3]]*10 + [df_rmi_wait_7.iloc[0,3]]*10+ [df_rmi_wait_8.iloc[0,3]]*10 + [df_rmi_wait_9.iloc[0,3]]*10
df_rmi_wait_male_s2 = [df_rmi_wait_0.iloc[1,3]]*10 + [df_rmi_wait_1.iloc[1,3]]*10 + [df_rmi_wait_2.iloc[1,3]]*10 + [df_rmi_wait_3.iloc[1,3]]*10+ [df_rmi_wait_4.iloc[1,3]]*10 + [df_rmi_wait_5.iloc[1,3]]*10+ [df_rmi_wait_6.iloc[1,3]]*10 + [df_rmi_wait_7.iloc[1,3]]*10+ [df_rmi_wait_8.iloc[1,3]]*10 + [df_rmi_wait_9.iloc[1,3]]*10
df_rmi_wait_noncis_s2 = [df_rmi_wait_0.iloc[2,3]]*10 + [df_rmi_wait_1.iloc[2,3]]*10 + [df_rmi_wait_2.iloc[2,3]]*10 + [df_rmi_wait_3.iloc[2,3]]*10+ [df_rmi_wait_4.iloc[2,3]]*10 + [df_rmi_wait_5.iloc[2,3]]*10+ [df_rmi_wait_6.iloc[2,3]]*10 + [df_rmi_wait_7.iloc[2,3]]*10+ [df_rmi_wait_8.iloc[2,3]]*10 + [df_rmi_wait_9.iloc[2,3]]*10

df_rmi_wait_older21_s2 = [df_rmi_wait_0.iloc[3,3]]*10 + [df_rmi_wait_1.iloc[3,3]]*10 + [df_rmi_wait_2.iloc[3,3]]*10 + [df_rmi_wait_3.iloc[3,3]]*10+ [df_rmi_wait_4.iloc[3,3]]*10 + [df_rmi_wait_5.iloc[3,3]]*10+ [df_rmi_wait_6.iloc[3,3]]*10 + [df_rmi_wait_7.iloc[3,3]]*10+ [df_rmi_wait_8.iloc[3,3]]*10 + [df_rmi_wait_9.iloc[3,3]]*10
df_rmi_wait_younger21_s2 = [df_rmi_wait_0.iloc[4,3]]*10 + [df_rmi_wait_1.iloc[4,3]]*10 + [df_rmi_wait_2.iloc[4,3]]*10 + [df_rmi_wait_3.iloc[4,3]]*10+ [df_rmi_wait_4.iloc[4,3]]*10 + [df_rmi_wait_5.iloc[4,3]]*10+ [df_rmi_wait_6.iloc[4,3]]*10 + [df_rmi_wait_7.iloc[4,3]]*10+ [df_rmi_wait_8.iloc[4,3]]*10 + [df_rmi_wait_9.iloc[4,3]]*10

df_rmi_wait_withchild_s2 = [df_rmi_wait_0.iloc[5,3]]*10 + [df_rmi_wait_1.iloc[5,3]]*10 + [df_rmi_wait_2.iloc[5,3]]*10 + [df_rmi_wait_3.iloc[5,3]]*10+ [df_rmi_wait_4.iloc[5,3]]*10 + [df_rmi_wait_5.iloc[5,3]]*10+ [df_rmi_wait_6.iloc[5,3]]*10 + [df_rmi_wait_7.iloc[5,3]]*10+ [df_rmi_wait_8.iloc[5,3]]*10 + [df_rmi_wait_9.iloc[5,3]]*10
df_rmi_wait_nochild_s2 = [df_rmi_wait_0.iloc[6,3]]*10 + [df_rmi_wait_1.iloc[6,3]]*10 + [df_rmi_wait_2.iloc[6,3]]*10 + [df_rmi_wait_3.iloc[6,3]]*10+ [df_rmi_wait_4.iloc[6,3]]*10 + [df_rmi_wait_5.iloc[6,3]]*10+ [df_rmi_wait_6.iloc[6,3]]*10 + [df_rmi_wait_7.iloc[6,3]]*10+ [df_rmi_wait_8.iloc[6,3]]*10 + [df_rmi_wait_9.iloc[6,3]]*10

df_rmi_wait_immigrant_s2 = [df_rmi_wait_0.iloc[7,3]]*10 + [df_rmi_wait_1.iloc[7,3]]*10 + [df_rmi_wait_2.iloc[7,3]]*10 + [df_rmi_wait_3.iloc[7,3]]*10+ [df_rmi_wait_4.iloc[7,3]]*10 + [df_rmi_wait_5.iloc[7,3]]*10+ [df_rmi_wait_6.iloc[7,3]]*10 + [df_rmi_wait_7.iloc[7,3]]*10+ [df_rmi_wait_8.iloc[7,3]]*10 + [df_rmi_wait_9.iloc[7,3]]*10
df_rmi_wait_notimmigrant_s2 = [df_rmi_wait_0.iloc[8,3]]*10 + [df_rmi_wait_1.iloc[8,3]]*10 + [df_rmi_wait_2.iloc[8,3]]*10 + [df_rmi_wait_3.iloc[8,3]]*10+ [df_rmi_wait_4.iloc[8,3]]*10 + [df_rmi_wait_5.iloc[8,3]]*10+ [df_rmi_wait_6.iloc[8,3]]*10 + [df_rmi_wait_7.iloc[8,3]]*10+ [df_rmi_wait_8.iloc[8,3]]*10 + [df_rmi_wait_9.iloc[8,3]]*10

df_rmi_wait_htvictim_s2 = [df_rmi_wait_0.iloc[9,3]]*10 + [df_rmi_wait_1.iloc[9,3]]*10 + [df_rmi_wait_2.iloc[9,3]]*10 + [df_rmi_wait_3.iloc[9,3]]*10+ [df_rmi_wait_4.iloc[9,3]]*10 + [df_rmi_wait_5.iloc[9,3]]*10+ [df_rmi_wait_6.iloc[9,3]]*10 + [df_rmi_wait_7.iloc[9,3]]*10+ [df_rmi_wait_8.iloc[9,3]]*10 + [df_rmi_wait_9.iloc[9,3]]*10
df_rmi_wait_nothtvictim_s2 = [df_rmi_wait_0.iloc[10,3]]*10 + [df_rmi_wait_1.iloc[10,3]]*10 + [df_rmi_wait_2.iloc[10,3]]*10 + [df_rmi_wait_3.iloc[10,3]]*10+ [df_rmi_wait_4.iloc[10,3]]*10 + [df_rmi_wait_5.iloc[10,3]]*10+ [df_rmi_wait_6.iloc[10,3]]*10 + [df_rmi_wait_7.iloc[10,3]]*10+ [df_rmi_wait_8.iloc[10,3]]*10 + [df_rmi_wait_9.iloc[10,3]]*10

#Datasets for number of youth arriving
df_rmi_arriving_female_s2 = [df_rmi_arriving_0.iloc[0,3]]*10 + [df_rmi_arriving_1.iloc[0,3]]*10 + [df_rmi_arriving_2.iloc[0,3]]*10 + [df_rmi_arriving_3.iloc[0,3]]*10+ [df_rmi_arriving_4.iloc[0,3]]*10 + [df_rmi_arriving_5.iloc[0,3]]*10+ [df_rmi_arriving_6.iloc[0,3]]*10 + [df_rmi_arriving_7.iloc[0,3]]*10+ [df_rmi_arriving_8.iloc[0,3]]*10 + [df_rmi_arriving_9.iloc[0,3]]*10
df_rmi_arriving_male_s2 = [df_rmi_arriving_0.iloc[1,3]]*10 + [df_rmi_arriving_1.iloc[1,3]]*10 + [df_rmi_arriving_2.iloc[1,3]]*10 + [df_rmi_arriving_3.iloc[1,3]]*10+ [df_rmi_arriving_4.iloc[1,3]]*10 + [df_rmi_arriving_5.iloc[1,3]]*10+ [df_rmi_arriving_6.iloc[1,3]]*10 + [df_rmi_arriving_7.iloc[1,3]]*10+ [df_rmi_arriving_8.iloc[1,3]]*10 + [df_rmi_arriving_9.iloc[1,3]]*10
df_rmi_arriving_noncis_s2 = [df_rmi_arriving_0.iloc[2,3]]*10 + [df_rmi_arriving_1.iloc[2,3]]*10 + [df_rmi_arriving_2.iloc[2,3]]*10 + [df_rmi_arriving_3.iloc[2,3]]*10+ [df_rmi_arriving_4.iloc[2,3]]*10 + [df_rmi_arriving_5.iloc[2,3]]*10+ [df_rmi_arriving_6.iloc[2,3]]*10 + [df_rmi_arriving_7.iloc[2,3]]*10+ [df_rmi_arriving_8.iloc[2,3]]*10 + [df_rmi_arriving_9.iloc[2,3]]*10

df_rmi_arriving_older21_s2 = [df_rmi_arriving_0.iloc[3,3]]*10 + [df_rmi_arriving_1.iloc[3,3]]*10 + [df_rmi_arriving_2.iloc[3,3]]*10 + [df_rmi_arriving_3.iloc[3,3]]*10+ [df_rmi_arriving_4.iloc[3,3]]*10 + [df_rmi_arriving_5.iloc[3,3]]*10+ [df_rmi_arriving_6.iloc[3,3]]*10 + [df_rmi_arriving_7.iloc[3,3]]*10+ [df_rmi_arriving_8.iloc[3,3]]*10 + [df_rmi_arriving_9.iloc[3,3]]*10
df_rmi_arriving_younger21_s2 = [df_rmi_arriving_0.iloc[4,3]]*10 + [df_rmi_arriving_1.iloc[4,3]]*10 + [df_rmi_arriving_2.iloc[4,3]]*10 + [df_rmi_arriving_3.iloc[4,3]]*10+ [df_rmi_arriving_4.iloc[4,3]]*10 + [df_rmi_arriving_5.iloc[4,3]]*10+ [df_rmi_arriving_6.iloc[4,3]]*10 + [df_rmi_arriving_7.iloc[4,3]]*10+ [df_rmi_arriving_8.iloc[4,3]]*10 + [df_rmi_arriving_9.iloc[4,3]]*10

df_rmi_arriving_withchild_s2 = [df_rmi_arriving_0.iloc[5,3]]*10 + [df_rmi_arriving_1.iloc[5,3]]*10 + [df_rmi_arriving_2.iloc[5,3]]*10 + [df_rmi_arriving_3.iloc[5,3]]*10+ [df_rmi_arriving_4.iloc[5,3]]*10 + [df_rmi_arriving_5.iloc[5,3]]*10+ [df_rmi_arriving_6.iloc[5,3]]*10 + [df_rmi_arriving_7.iloc[5,3]]*10+ [df_rmi_arriving_8.iloc[5,3]]*10 + [df_rmi_arriving_9.iloc[5,3]]*10
df_rmi_arriving_nochild_s2 = [df_rmi_arriving_0.iloc[6,3]]*10 + [df_rmi_arriving_1.iloc[6,3]]*10 + [df_rmi_arriving_2.iloc[6,3]]*10 + [df_rmi_arriving_3.iloc[6,3]]*10+ [df_rmi_arriving_4.iloc[6,3]]*10 + [df_rmi_arriving_5.iloc[6,3]]*10+ [df_rmi_arriving_6.iloc[6,3]]*10 + [df_rmi_arriving_7.iloc[6,3]]*10+ [df_rmi_arriving_8.iloc[6,3]]*10 + [df_rmi_arriving_9.iloc[6,3]]*10

df_rmi_arriving_immigrant_s2 = [df_rmi_arriving_0.iloc[7,3]]*10 + [df_rmi_arriving_1.iloc[7,3]]*10 + [df_rmi_arriving_2.iloc[7,3]]*10 + [df_rmi_arriving_3.iloc[7,3]]*10+ [df_rmi_arriving_4.iloc[7,3]]*10 + [df_rmi_arriving_5.iloc[7,3]]*10+ [df_rmi_arriving_6.iloc[7,3]]*10 + [df_rmi_arriving_7.iloc[7,3]]*10+ [df_rmi_arriving_8.iloc[7,3]]*10 + [df_rmi_arriving_9.iloc[7,3]]*10
df_rmi_arriving_notimmigrant_s2 = [df_rmi_arriving_0.iloc[8,3]]*10 + [df_rmi_arriving_1.iloc[8,3]]*10 + [df_rmi_arriving_2.iloc[8,3]]*10 + [df_rmi_arriving_3.iloc[8,3]]*10+ [df_rmi_arriving_4.iloc[8,3]]*10 + [df_rmi_arriving_5.iloc[8,3]]*10+ [df_rmi_arriving_6.iloc[8,3]]*10 + [df_rmi_arriving_7.iloc[8,3]]*10+ [df_rmi_arriving_8.iloc[8,3]]*10 + [df_rmi_arriving_9.iloc[8,3]]*10

df_rmi_arriving_htvictim_s2 = [df_rmi_arriving_0.iloc[9,3]]*10 + [df_rmi_arriving_1.iloc[9,3]]*10 + [df_rmi_arriving_2.iloc[9,3]]*10 + [df_rmi_arriving_3.iloc[9,3]]*10+ [df_rmi_arriving_4.iloc[9,3]]*10 + [df_rmi_arriving_5.iloc[9,3]]*10+ [df_rmi_arriving_6.iloc[9,3]]*10 + [df_rmi_arriving_7.iloc[9,3]]*10+ [df_rmi_arriving_8.iloc[9,3]]*10 + [df_rmi_arriving_9.iloc[9,3]]*10
df_rmi_arriving_nothtvictim_s2 = [df_rmi_arriving_0.iloc[10,3]]*10 + [df_rmi_arriving_1.iloc[10,3]]*10 + [df_rmi_arriving_2.iloc[10,3]]*10 + [df_rmi_arriving_3.iloc[10,3]]*10+ [df_rmi_arriving_4.iloc[10,3]]*10 + [df_rmi_arriving_5.iloc[10,3]]*10+ [df_rmi_arriving_6.iloc[10,3]]*10 + [df_rmi_arriving_7.iloc[10,3]]*10+ [df_rmi_arriving_8.iloc[10,3]]*10 + [df_rmi_arriving_9.iloc[10,3]]*10

# %% [markdown]
# __For shelter 3 metrics__

# %%
#Datasets for abandonment percentage
df_rmi_abandonment_female_s3 = [df_rmi_abandonment_0.iloc[0,4]]*10 + [df_rmi_abandonment_1.iloc[0,4]]*10 + [df_rmi_abandonment_2.iloc[0,4]]*10 + [df_rmi_abandonment_3.iloc[0,4]]*10+ [df_rmi_abandonment_4.iloc[0,4]]*10 + [df_rmi_abandonment_5.iloc[0,4]]*10+ [df_rmi_abandonment_6.iloc[0,4]]*10 + [df_rmi_abandonment_7.iloc[0,4]]*10+ [df_rmi_abandonment_8.iloc[0,4]]*10 + [df_rmi_abandonment_9.iloc[0,4]]*10
df_rmi_abandonment_male_s3 = [df_rmi_abandonment_0.iloc[1,4]]*10 + [df_rmi_abandonment_1.iloc[1,4]]*10 + [df_rmi_abandonment_2.iloc[1,4]]*10 + [df_rmi_abandonment_3.iloc[1,4]]*10+ [df_rmi_abandonment_4.iloc[1,4]]*10 + [df_rmi_abandonment_5.iloc[1,4]]*10+ [df_rmi_abandonment_6.iloc[1,4]]*10 + [df_rmi_abandonment_7.iloc[1,4]]*10+ [df_rmi_abandonment_8.iloc[1,4]]*10 + [df_rmi_abandonment_9.iloc[1,4]]*10
df_rmi_abandonment_noncis_s3 = [df_rmi_abandonment_0.iloc[2,4]]*10 + [df_rmi_abandonment_1.iloc[2,4]]*10 + [df_rmi_abandonment_2.iloc[2,4]]*10 + [df_rmi_abandonment_3.iloc[2,4]]*10+ [df_rmi_abandonment_4.iloc[2,4]]*10 + [df_rmi_abandonment_5.iloc[2,4]]*10+ [df_rmi_abandonment_6.iloc[2,4]]*10 + [df_rmi_abandonment_7.iloc[2,4]]*10+ [df_rmi_abandonment_8.iloc[2,4]]*10 + [df_rmi_abandonment_9.iloc[2,4]]*10

df_rmi_abandonment_older21_s3 = [df_rmi_abandonment_0.iloc[3,4]]*10 + [df_rmi_abandonment_1.iloc[3,4]]*10 + [df_rmi_abandonment_2.iloc[3,4]]*10 + [df_rmi_abandonment_3.iloc[3,4]]*10+ [df_rmi_abandonment_4.iloc[3,4]]*10 + [df_rmi_abandonment_5.iloc[3,4]]*10+ [df_rmi_abandonment_6.iloc[3,4]]*10 + [df_rmi_abandonment_7.iloc[3,4]]*10+ [df_rmi_abandonment_8.iloc[3,4]]*10 + [df_rmi_abandonment_9.iloc[3,4]]*10
df_rmi_abandonment_younger21_s3 = [df_rmi_abandonment_0.iloc[4,4]]*10 + [df_rmi_abandonment_1.iloc[4,4]]*10 + [df_rmi_abandonment_2.iloc[4,4]]*10 + [df_rmi_abandonment_3.iloc[4,4]]*10+ [df_rmi_abandonment_4.iloc[4,4]]*10 + [df_rmi_abandonment_5.iloc[4,4]]*10+ [df_rmi_abandonment_6.iloc[4,4]]*10 + [df_rmi_abandonment_7.iloc[4,4]]*10+ [df_rmi_abandonment_8.iloc[4,4]]*10 + [df_rmi_abandonment_9.iloc[4,4]]*10

df_rmi_abandonment_withchild_s3 = [df_rmi_abandonment_0.iloc[5,4]]*10 + [df_rmi_abandonment_1.iloc[5,4]]*10 + [df_rmi_abandonment_2.iloc[5,4]]*10 + [df_rmi_abandonment_3.iloc[5,4]]*10+ [df_rmi_abandonment_4.iloc[5,4]]*10 + [df_rmi_abandonment_5.iloc[5,4]]*10+ [df_rmi_abandonment_6.iloc[5,4]]*10 + [df_rmi_abandonment_7.iloc[5,4]]*10+ [df_rmi_abandonment_8.iloc[5,4]]*10 + [df_rmi_abandonment_9.iloc[5,4]]*10
df_rmi_abandonment_nochild_s3 = [df_rmi_abandonment_0.iloc[6,4]]*10 + [df_rmi_abandonment_1.iloc[6,4]]*10 + [df_rmi_abandonment_2.iloc[6,4]]*10 + [df_rmi_abandonment_3.iloc[6,4]]*10+ [df_rmi_abandonment_4.iloc[6,4]]*10 + [df_rmi_abandonment_5.iloc[6,4]]*10+ [df_rmi_abandonment_6.iloc[6,4]]*10 + [df_rmi_abandonment_7.iloc[6,4]]*10+ [df_rmi_abandonment_8.iloc[6,4]]*10 + [df_rmi_abandonment_9.iloc[6,4]]*10

df_rmi_abandonment_immigrant_s3 = [df_rmi_abandonment_0.iloc[7,4]]*10 + [df_rmi_abandonment_1.iloc[7,4]]*10 + [df_rmi_abandonment_2.iloc[7,4]]*10 + [df_rmi_abandonment_3.iloc[7,4]]*10+ [df_rmi_abandonment_4.iloc[7,4]]*10 + [df_rmi_abandonment_5.iloc[7,4]]*10+ [df_rmi_abandonment_6.iloc[7,4]]*10 + [df_rmi_abandonment_7.iloc[7,4]]*10+ [df_rmi_abandonment_8.iloc[7,4]]*10 + [df_rmi_abandonment_9.iloc[7,4]]*10
df_rmi_abandonment_notimmigrant_s3 = [df_rmi_abandonment_0.iloc[8,4]]*10 + [df_rmi_abandonment_1.iloc[8,4]]*10 + [df_rmi_abandonment_2.iloc[8,4]]*10 + [df_rmi_abandonment_3.iloc[8,4]]*10+ [df_rmi_abandonment_4.iloc[8,4]]*10 + [df_rmi_abandonment_5.iloc[8,4]]*10+ [df_rmi_abandonment_6.iloc[8,4]]*10 + [df_rmi_abandonment_7.iloc[8,4]]*10+ [df_rmi_abandonment_8.iloc[8,4]]*10 + [df_rmi_abandonment_9.iloc[8,4]]*10

df_rmi_abandonment_htvictim_s3 = [df_rmi_abandonment_0.iloc[9,4]]*10 + [df_rmi_abandonment_1.iloc[9,4]]*10 + [df_rmi_abandonment_2.iloc[9,4]]*10 + [df_rmi_abandonment_3.iloc[9,4]]*10+ [df_rmi_abandonment_4.iloc[9,4]]*10 + [df_rmi_abandonment_5.iloc[9,4]]*10+ [df_rmi_abandonment_6.iloc[9,4]]*10 + [df_rmi_abandonment_7.iloc[9,4]]*10+ [df_rmi_abandonment_8.iloc[9,4]]*10 + [df_rmi_abandonment_9.iloc[9,4]]*10
df_rmi_abandonment_nothtvictim_s3 = [df_rmi_abandonment_0.iloc[10,4]]*10 + [df_rmi_abandonment_1.iloc[10,4]]*10 + [df_rmi_abandonment_2.iloc[10,4]]*10 + [df_rmi_abandonment_3.iloc[10,4]]*10+ [df_rmi_abandonment_4.iloc[10,4]]*10 + [df_rmi_abandonment_5.iloc[10,4]]*10+ [df_rmi_abandonment_6.iloc[10,4]]*10 + [df_rmi_abandonment_7.iloc[10,4]]*10+ [df_rmi_abandonment_8.iloc[10,4]]*10 + [df_rmi_abandonment_9.iloc[10,4]]*10

#Datasets for average wait
df_rmi_wait_female_s3 = [df_rmi_wait_0.iloc[0,4]]*10 + [df_rmi_wait_1.iloc[0,4]]*10 + [df_rmi_wait_2.iloc[0,4]]*10 + [df_rmi_wait_3.iloc[0,4]]*10+ [df_rmi_wait_4.iloc[0,4]]*10 + [df_rmi_wait_5.iloc[0,4]]*10+ [df_rmi_wait_6.iloc[0,4]]*10 + [df_rmi_wait_7.iloc[0,4]]*10+ [df_rmi_wait_8.iloc[0,4]]*10 + [df_rmi_wait_9.iloc[0,4]]*10
df_rmi_wait_male_s3 = [df_rmi_wait_0.iloc[1,4]]*10 + [df_rmi_wait_1.iloc[1,4]]*10 + [df_rmi_wait_2.iloc[1,4]]*10 + [df_rmi_wait_3.iloc[1,4]]*10+ [df_rmi_wait_4.iloc[1,4]]*10 + [df_rmi_wait_5.iloc[1,4]]*10+ [df_rmi_wait_6.iloc[1,4]]*10 + [df_rmi_wait_7.iloc[1,4]]*10+ [df_rmi_wait_8.iloc[1,4]]*10 + [df_rmi_wait_9.iloc[1,4]]*10
df_rmi_wait_noncis_s3 = [df_rmi_wait_0.iloc[2,4]]*10 + [df_rmi_wait_1.iloc[2,4]]*10 + [df_rmi_wait_2.iloc[2,4]]*10 + [df_rmi_wait_3.iloc[2,4]]*10+ [df_rmi_wait_4.iloc[2,4]]*10 + [df_rmi_wait_5.iloc[2,4]]*10+ [df_rmi_wait_6.iloc[2,4]]*10 + [df_rmi_wait_7.iloc[2,4]]*10+ [df_rmi_wait_8.iloc[2,4]]*10 + [df_rmi_wait_9.iloc[2,4]]*10

df_rmi_wait_older21_s3 = [df_rmi_wait_0.iloc[3,4]]*10 + [df_rmi_wait_1.iloc[3,4]]*10 + [df_rmi_wait_2.iloc[3,4]]*10 + [df_rmi_wait_3.iloc[3,4]]*10+ [df_rmi_wait_4.iloc[3,4]]*10 + [df_rmi_wait_5.iloc[3,4]]*10+ [df_rmi_wait_6.iloc[3,4]]*10 + [df_rmi_wait_7.iloc[3,4]]*10+ [df_rmi_wait_8.iloc[3,4]]*10 + [df_rmi_wait_9.iloc[3,4]]*10
df_rmi_wait_younger21_s3 = [df_rmi_wait_0.iloc[4,4]]*10 + [df_rmi_wait_1.iloc[4,4]]*10 + [df_rmi_wait_2.iloc[4,4]]*10 + [df_rmi_wait_3.iloc[4,4]]*10+ [df_rmi_wait_4.iloc[4,4]]*10 + [df_rmi_wait_5.iloc[4,4]]*10+ [df_rmi_wait_6.iloc[4,4]]*10 + [df_rmi_wait_7.iloc[4,4]]*10+ [df_rmi_wait_8.iloc[4,4]]*10 + [df_rmi_wait_9.iloc[4,4]]*10

df_rmi_wait_withchild_s3 = [df_rmi_wait_0.iloc[5,4]]*10 + [df_rmi_wait_1.iloc[5,4]]*10 + [df_rmi_wait_2.iloc[5,4]]*10 + [df_rmi_wait_3.iloc[5,4]]*10+ [df_rmi_wait_4.iloc[5,4]]*10 + [df_rmi_wait_5.iloc[5,4]]*10+ [df_rmi_wait_6.iloc[5,4]]*10 + [df_rmi_wait_7.iloc[5,4]]*10+ [df_rmi_wait_8.iloc[5,4]]*10 + [df_rmi_wait_9.iloc[5,4]]*10
df_rmi_wait_nochild_s3 = [df_rmi_wait_0.iloc[6,4]]*10 + [df_rmi_wait_1.iloc[6,4]]*10 + [df_rmi_wait_2.iloc[6,4]]*10 + [df_rmi_wait_3.iloc[6,4]]*10+ [df_rmi_wait_4.iloc[6,4]]*10 + [df_rmi_wait_5.iloc[6,4]]*10+ [df_rmi_wait_6.iloc[6,4]]*10 + [df_rmi_wait_7.iloc[6,4]]*10+ [df_rmi_wait_8.iloc[6,4]]*10 + [df_rmi_wait_9.iloc[6,4]]*10

df_rmi_wait_immigrant_s3 = [df_rmi_wait_0.iloc[7,4]]*10 + [df_rmi_wait_1.iloc[7,4]]*10 + [df_rmi_wait_2.iloc[7,4]]*10 + [df_rmi_wait_3.iloc[7,4]]*10+ [df_rmi_wait_4.iloc[7,4]]*10 + [df_rmi_wait_5.iloc[7,4]]*10+ [df_rmi_wait_6.iloc[7,4]]*10 + [df_rmi_wait_7.iloc[7,4]]*10+ [df_rmi_wait_8.iloc[7,4]]*10 + [df_rmi_wait_9.iloc[7,4]]*10
df_rmi_wait_notimmigrant_s3 = [df_rmi_wait_0.iloc[8,4]]*10 + [df_rmi_wait_1.iloc[8,4]]*10 + [df_rmi_wait_2.iloc[8,4]]*10 + [df_rmi_wait_3.iloc[8,4]]*10+ [df_rmi_wait_4.iloc[8,4]]*10 + [df_rmi_wait_5.iloc[8,4]]*10+ [df_rmi_wait_6.iloc[8,4]]*10 + [df_rmi_wait_7.iloc[8,4]]*10+ [df_rmi_wait_8.iloc[8,4]]*10 + [df_rmi_wait_9.iloc[8,4]]*10

df_rmi_wait_htvictim_s3 = [df_rmi_wait_0.iloc[9,4]]*10 + [df_rmi_wait_1.iloc[9,4]]*10 + [df_rmi_wait_2.iloc[9,4]]*10 + [df_rmi_wait_3.iloc[9,4]]*10+ [df_rmi_wait_4.iloc[9,4]]*10 + [df_rmi_wait_5.iloc[9,4]]*10+ [df_rmi_wait_6.iloc[9,4]]*10 + [df_rmi_wait_7.iloc[9,4]]*10+ [df_rmi_wait_8.iloc[9,4]]*10 + [df_rmi_wait_9.iloc[9,4]]*10
df_rmi_wait_nothtvictim_s3 = [df_rmi_wait_0.iloc[10,4]]*10 + [df_rmi_wait_1.iloc[10,4]]*10 + [df_rmi_wait_2.iloc[10,4]]*10 + [df_rmi_wait_3.iloc[10,4]]*10+ [df_rmi_wait_4.iloc[10,4]]*10 + [df_rmi_wait_5.iloc[10,4]]*10+ [df_rmi_wait_6.iloc[10,4]]*10 + [df_rmi_wait_7.iloc[10,4]]*10+ [df_rmi_wait_8.iloc[10,4]]*10 + [df_rmi_wait_9.iloc[10,4]]*10

#Datasets for number of youth arriving
df_rmi_arriving_female_s3 = [df_rmi_arriving_0.iloc[0,4]]*10 + [df_rmi_arriving_1.iloc[0,4]]*10 + [df_rmi_arriving_2.iloc[0,4]]*10 + [df_rmi_arriving_3.iloc[0,4]]*10+ [df_rmi_arriving_4.iloc[0,4]]*10 + [df_rmi_arriving_5.iloc[0,4]]*10+ [df_rmi_arriving_6.iloc[0,4]]*10 + [df_rmi_arriving_7.iloc[0,4]]*10+ [df_rmi_arriving_8.iloc[0,4]]*10 + [df_rmi_arriving_9.iloc[0,4]]*10
df_rmi_arriving_male_s3 = [df_rmi_arriving_0.iloc[1,4]]*10 + [df_rmi_arriving_1.iloc[1,4]]*10 + [df_rmi_arriving_2.iloc[1,4]]*10 + [df_rmi_arriving_3.iloc[1,4]]*10+ [df_rmi_arriving_4.iloc[1,4]]*10 + [df_rmi_arriving_5.iloc[1,4]]*10+ [df_rmi_arriving_6.iloc[1,4]]*10 + [df_rmi_arriving_7.iloc[1,4]]*10+ [df_rmi_arriving_8.iloc[1,4]]*10 + [df_rmi_arriving_9.iloc[1,4]]*10
df_rmi_arriving_noncis_s3 = [df_rmi_arriving_0.iloc[2,4]]*10 + [df_rmi_arriving_1.iloc[2,4]]*10 + [df_rmi_arriving_2.iloc[2,4]]*10 + [df_rmi_arriving_3.iloc[2,4]]*10+ [df_rmi_arriving_4.iloc[2,4]]*10 + [df_rmi_arriving_5.iloc[2,4]]*10+ [df_rmi_arriving_6.iloc[2,4]]*10 + [df_rmi_arriving_7.iloc[2,4]]*10+ [df_rmi_arriving_8.iloc[2,4]]*10 + [df_rmi_arriving_9.iloc[2,4]]*10

df_rmi_arriving_older21_s3 = [df_rmi_arriving_0.iloc[3,4]]*10 + [df_rmi_arriving_1.iloc[3,4]]*10 + [df_rmi_arriving_2.iloc[3,4]]*10 + [df_rmi_arriving_3.iloc[3,4]]*10+ [df_rmi_arriving_4.iloc[3,4]]*10 + [df_rmi_arriving_5.iloc[3,4]]*10+ [df_rmi_arriving_6.iloc[3,4]]*10 + [df_rmi_arriving_7.iloc[3,4]]*10+ [df_rmi_arriving_8.iloc[3,4]]*10 + [df_rmi_arriving_9.iloc[3,4]]*10
df_rmi_arriving_younger21_s3 = [df_rmi_arriving_0.iloc[4,4]]*10 + [df_rmi_arriving_1.iloc[4,4]]*10 + [df_rmi_arriving_2.iloc[4,4]]*10 + [df_rmi_arriving_3.iloc[4,4]]*10+ [df_rmi_arriving_4.iloc[4,4]]*10 + [df_rmi_arriving_5.iloc[4,4]]*10+ [df_rmi_arriving_6.iloc[4,4]]*10 + [df_rmi_arriving_7.iloc[4,4]]*10+ [df_rmi_arriving_8.iloc[4,4]]*10 + [df_rmi_arriving_9.iloc[4,4]]*10

df_rmi_arriving_withchild_s3 = [df_rmi_arriving_0.iloc[5,4]]*10 + [df_rmi_arriving_1.iloc[5,4]]*10 + [df_rmi_arriving_2.iloc[5,4]]*10 + [df_rmi_arriving_3.iloc[5,4]]*10+ [df_rmi_arriving_4.iloc[5,4]]*10 + [df_rmi_arriving_5.iloc[5,4]]*10+ [df_rmi_arriving_6.iloc[5,4]]*10 + [df_rmi_arriving_7.iloc[5,4]]*10+ [df_rmi_arriving_8.iloc[5,4]]*10 + [df_rmi_arriving_9.iloc[5,4]]*10
df_rmi_arriving_nochild_s3 = [df_rmi_arriving_0.iloc[6,4]]*10 + [df_rmi_arriving_1.iloc[6,4]]*10 + [df_rmi_arriving_2.iloc[6,4]]*10 + [df_rmi_arriving_3.iloc[6,4]]*10+ [df_rmi_arriving_4.iloc[6,4]]*10 + [df_rmi_arriving_5.iloc[6,4]]*10+ [df_rmi_arriving_6.iloc[6,4]]*10 + [df_rmi_arriving_7.iloc[6,4]]*10+ [df_rmi_arriving_8.iloc[6,4]]*10 + [df_rmi_arriving_9.iloc[6,4]]*10

df_rmi_arriving_immigrant_s3 = [df_rmi_arriving_0.iloc[7,4]]*10 + [df_rmi_arriving_1.iloc[7,4]]*10 + [df_rmi_arriving_2.iloc[7,4]]*10 + [df_rmi_arriving_3.iloc[7,4]]*10+ [df_rmi_arriving_4.iloc[7,4]]*10 + [df_rmi_arriving_5.iloc[7,4]]*10+ [df_rmi_arriving_6.iloc[7,4]]*10 + [df_rmi_arriving_7.iloc[7,4]]*10+ [df_rmi_arriving_8.iloc[7,4]]*10 + [df_rmi_arriving_9.iloc[7,4]]*10
df_rmi_arriving_notimmigrant_s3 = [df_rmi_arriving_0.iloc[8,4]]*10 + [df_rmi_arriving_1.iloc[8,4]]*10 + [df_rmi_arriving_2.iloc[8,4]]*10 + [df_rmi_arriving_3.iloc[8,4]]*10+ [df_rmi_arriving_4.iloc[8,4]]*10 + [df_rmi_arriving_5.iloc[8,4]]*10+ [df_rmi_arriving_6.iloc[8,4]]*10 + [df_rmi_arriving_7.iloc[8,4]]*10+ [df_rmi_arriving_8.iloc[8,4]]*10 + [df_rmi_arriving_9.iloc[8,4]]*10

df_rmi_arriving_htvictim_s3 = [df_rmi_arriving_0.iloc[9,4]]*10 + [df_rmi_arriving_1.iloc[9,4]]*10 + [df_rmi_arriving_2.iloc[9,4]]*10 + [df_rmi_arriving_3.iloc[9,4]]*10+ [df_rmi_arriving_4.iloc[9,4]]*10 + [df_rmi_arriving_5.iloc[9,4]]*10+ [df_rmi_arriving_6.iloc[9,4]]*10 + [df_rmi_arriving_7.iloc[9,4]]*10+ [df_rmi_arriving_8.iloc[9,4]]*10 + [df_rmi_arriving_9.iloc[9,4]]*10
df_rmi_arriving_nothtvictim_s3 = [df_rmi_arriving_0.iloc[10,4]]*10 + [df_rmi_arriving_1.iloc[10,4]]*10 + [df_rmi_arriving_2.iloc[10,4]]*10 + [df_rmi_arriving_3.iloc[10,4]]*10+ [df_rmi_arriving_4.iloc[10,4]]*10 + [df_rmi_arriving_5.iloc[10,4]]*10+ [df_rmi_arriving_6.iloc[10,4]]*10 + [df_rmi_arriving_7.iloc[10,4]]*10+ [df_rmi_arriving_8.iloc[10,4]]*10 + [df_rmi_arriving_9.iloc[10,4]]*10

# %% [markdown]
# ***Tests for Abandonment Rate***

# %%
#Data for abandonment

summary_table = pd.DataFrame(
    {'Characteristic': ['Male','Female', 'Non-cisgender', 'Older 21', 'Younger 21', 'Immigrant',
                        'NotImmigrant', 'HT', 'No HT'],
     'Mean % abandoning': [ mean(df_rmi_abandonment_male), mean(df_rmi_abandonment_female), mean(df_rmi_abandonment_noncis), 
                            mean(df_rmi_abandonment_older21), mean(df_rmi_abandonment_younger21), 
                           mean(df_rmi_abandonment_immigrant), mean(df_rmi_abandonment_notimmigrant), 
                            mean(df_rmi_abandonment_htvictim), mean(df_rmi_abandonment_nothtvictim)],
     'Std dev % abandoning': [statistics.stdev(df_rmi_abandonment_male), statistics.stdev(df_rmi_abandonment_female), statistics.stdev(df_rmi_abandonment_noncis), 
                              statistics.stdev(df_rmi_abandonment_older21), statistics.stdev(df_rmi_abandonment_younger21),
                              statistics.stdev(df_rmi_abandonment_immigrant), statistics.stdev(df_rmi_abandonment_notimmigrant), 
                              statistics.stdev(df_rmi_abandonment_htvictim), statistics.stdev(df_rmi_abandonment_nothtvictim)],
     'N': [mean(df_rmi_arriving_male), mean(df_rmi_arriving_female), mean(df_rmi_arriving_noncis), 
                            mean(df_rmi_arriving_older21), mean(df_rmi_arriving_younger21), 
           mean(df_rmi_arriving_immigrant), mean(df_rmi_arriving_notimmigrant), 
                            mean(df_rmi_arriving_htvictim), mean(df_rmi_arriving_nothtvictim)]
    })
display(summary_table)

data_aban = [df_rmi_abandonment_female, df_rmi_abandonment_male, df_rmi_abandonment_noncis, df_rmi_abandonment_older21, 
             df_rmi_abandonment_younger21,  df_rmi_abandonment_immigrant, 
             df_rmi_abandonment_notimmigrant, df_rmi_abandonment_htvictim, df_rmi_abandonment_nothtvictim ]


#Figure that show the difference of wait times for different genders
#plt.rc('text', usetex=True)
#plt.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]

fig = plt.figure(figsize =(10, 6))
ax = fig.add_subplot(111)
 
# Creating axes instance
bp = ax.boxplot(data_aban , patch_artist = True,
                notch ='True', vert = 0)
 
colors = ['indianred', 'indianred','indianred','#fc8d59', '#fc8d59', '#fee090','#fee090', '#91bfdb','#91bfdb']
 
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
 
# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='black',
                linewidth = 1.5,linestyle =":")
 
# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='black', linewidth = 2)
 
# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='black', linewidth = 3)
 
# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='black', alpha = 0.5)
     
# x-axis labels
ax.set_yticklabels(['Cisgender Man/Boy','Cisgender Woman/Girl', 'Non-Cisgender, LGBTQ+', 'Older than 21', 'Younger than 21',  'Immigrant',
                        'Not Immigrant', 'HT Victim', 'Not HT Victim'])
 
# Adding title
#plt.title("Customized box plot")

#labels and legend
plt.xlabel('Proportion of youth abandoning the queue')
#plt.ylabel(r'Characteristic')

#plt.grid(axis = 'x', color = 'gray', linestyle = '--', linewidth = 0.2)

plt.grid(which='major', color='#DDDDDD', linewidth=0.8)
# Show the minor grid as well. Style it in very light gray as a thin,
# dotted line.
plt.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
# Make the minor ticks and gridlines show.
plt.minorticks_on()

plt.rcParams["font.family"] = "serif"
plt.rcParams.update({'font.size': 26})

plt.xlim([0,0.7])
 
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

textbox = '\n'.join(['RMI'])

bbox = dict(boxstyle='square', facecolor='lightsteelblue', alpha=0.6)
fig.text(0.87,0.95,textbox,fontsize=26,transform=ax.transAxes, bbox=bbox, 
verticalalignment='top')
     
     
# show plot
plt.show()


# #Plot the means
# sns.pointplot(x = 'Characteristic', y = 'Mean % abandoning', data = summary_table, palette= sns.color_palette("Set2"))
# plt.grid(axis = 'both', color = 'gray', linestyle = '--', linewidth = 0.2)
# plt.show()
# Out:
#   Characteristic  Mean % abandoning  Std dev % abandoning         N
# 0           Male              0.107                 0.014   783.400
# 1         Female              0.108                 0.013   629.900
# 2  Non-cisgender              0.260                 0.035   475.400
# 3       Older 21              0.367                 0.026   196.700
# 4     Younger 21              0.119                 0.004 1,935.200
# 5      Immigrant              0.107                 0.010   301.100
# 6   NotImmigrant              0.147                 0.004 1,830.800
# 7             HT              0.131                 0.011   437.200
# 8          No HT              0.144                 0.006 1,694.700

# %%
#Test for abandonment rate equality 

alpha = 0.05 

#For gender groups
n_male = mean(df_rmi_arriving_male)
n_female = mean(df_rmi_arriving_female)
n_noncis = mean(df_rmi_arriving_noncis)
n_older21 = mean(df_rmi_arriving_older21)
n_younger21 = mean(df_rmi_arriving_younger21)
n_withchild = mean(df_rmi_arriving_withchild)
n_nochild = mean(df_rmi_arriving_nochild)
n_immigrant = mean(df_rmi_arriving_immigrant)
n_notimmigrant = mean(df_rmi_arriving_notimmigrant)
n_ht = mean(df_rmi_arriving_htvictim)
n_noht = mean(df_rmi_arriving_nothtvictim)

x_male = mean(df_rmi_abandonment_male)*mean(df_rmi_arriving_male)
x_female = mean(df_rmi_abandonment_female)*mean(df_rmi_arriving_female)
x_noncis = mean(df_rmi_abandonment_noncis)*mean(df_rmi_arriving_noncis)
x_older21 = mean(df_rmi_abandonment_older21)* mean(df_rmi_arriving_older21)
x_younger21 = mean(df_rmi_abandonment_younger21)*mean(df_rmi_arriving_younger21)
x_withchild = mean(df_rmi_abandonment_withchild)*mean(df_rmi_arriving_withchild)
x_nochild = mean(df_rmi_abandonment_nochild)*mean(df_rmi_arriving_nochild)
x_immigrant = mean(df_rmi_abandonment_immigrant)*mean(df_rmi_arriving_immigrant)
x_notimmigrant = mean(df_rmi_abandonment_notimmigrant)*mean(df_rmi_arriving_notimmigrant)
x_ht = mean(df_rmi_abandonment_htvictim)*mean(df_rmi_arriving_htvictim)
x_noht = mean(df_rmi_abandonment_nothtvictim)*mean(df_rmi_arriving_nothtvictim)

abandonment_cnts_mf = np.array([x_male, x_female])
total_cnts_mf = np.array([n_male, n_female])
test_stat_mf, pval_mf = proportions_ztest(count=abandonment_cnts_mf, nobs=total_cnts_mf, alternative='two-sided')

abandonment_cnts_mn = np.array([x_male, x_noncis])
total_cnts_mn = np.array([n_male, n_noncis])
test_stat_mn, pval_mn = proportions_ztest(count=abandonment_cnts_mn, nobs=total_cnts_mn, alternative='two-sided')

abandonment_cnts_fn = np.array([x_female, x_noncis])
total_cnts_fn = np.array([n_female, n_noncis])
test_stat_fn, pval_fn = proportions_ztest(count=abandonment_cnts_fn, nobs=total_cnts_fn, alternative='two-sided')

abandonment_cnts_age = np.array([x_older21, x_younger21])
total_cnts_age = np.array([n_older21, n_younger21])
test_stat_age, pval_age = proportions_ztest(count=abandonment_cnts_age, nobs=total_cnts_age, alternative='two-sided')

abandonment_cnts_immigrant = np.array([x_immigrant, x_notimmigrant])
total_cnts_immigrant = np.array([n_immigrant, n_notimmigrant])
test_stat_immigrant, pval_immigrant = proportions_ztest(count=abandonment_cnts_immigrant, nobs=total_cnts_immigrant, alternative='two-sided')

abandonment_cnts_child = np.array([x_withchild, x_nochild])
total_cnts_child = np.array([n_withchild, n_nochild])
test_stat_child, pval_child = proportions_ztest(count=abandonment_cnts_child, nobs=total_cnts_child, alternative='two-sided')

abandonment_cnts_ht = np.array([x_ht, x_noht])
total_cnts_ht = np.array([n_ht, n_noht])
test_stat_ht, pval_ht = proportions_ztest(count=abandonment_cnts_ht, nobs=total_cnts_ht, alternative='two-sided')


dict_abandonment = {'Comparisons' : ['Male-Female','Male-NonCisgender','Female-NonCisgender','Age','Having a Child',
                                                'Being an immigrant','Experiencing HT'],
        'Test statistic' : [test_stat_mf, test_stat_mn, test_stat_fn,test_stat_age, test_stat_child, test_stat_immigrant, 
                            test_stat_ht],
        'p-value' : [pval_mf, pval_mn, pval_fn, pval_age, pval_child, pval_immigrant, pval_ht]
       }
pd.options.display.float_format = '{:,.3f}'.format
df_abandonments = pd.DataFrame(dict_abandonment)
  
# displaying the DataFrame
display(df_abandonments)
# Out:
#            Comparisons  Test statistic  p-value
# 0          Male-Female          -0.049    0.961
# 1    Male-NonCisgender          -7.095    0.000
# 2  Female-NonCisgender          -6.620    0.000
# 3                  Age           9.502    0.000
# 4       Having a Child          -0.371    0.711
# 5   Being an immigrant          -1.870    0.062
# 6      Experiencing HT          -0.745    0.456

# %%
summary_table = pd.DataFrame(
    {'Shelter': ['Shelter 0','Shelter 1', 'Shelter 2', 'Shelter 3'],
     'Mean % abandonment': [ mean(df_rmi_abandonment_s0), mean(df_rmi_abandonment_s1), mean(df_rmi_abandonment_s2), mean(df_rmi_abandonment_s3)],
     'Std dev % abandonment': [statistics.stdev(df_rmi_abandonment_s0), statistics.stdev(df_rmi_abandonment_s1), statistics.stdev(df_rmi_abandonment_s2), statistics.stdev(df_rmi_abandonment_s3)],
     'N': [mean(df_rmi_arriving_s0), mean(df_rmi_arriving_s1), mean(df_rmi_arriving_s2), mean(df_rmi_arriving_s3)]
    })
display(summary_table)

data_wait = [df_rmi_abandonment_s0, df_rmi_abandonment_s1, df_rmi_abandonment_s2, df_rmi_abandonment_s3]

fig = plt.figure(figsize =(10, 6))
ax = fig.add_subplot(111)
 
# Creating axes instance
bp = ax.boxplot(data_wait , patch_artist = True,
                notch ='True', vert = 0)
 
colors = ['#bae4bc', '#bae4bc','#bae4bc', '#bae4bc']
 
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
 
# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='black',
                linewidth = 1.5,linestyle =":")
 
# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='black', linewidth = 2)
 
# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='black', linewidth = 3)
 
# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='black', alpha = 0.5)
     
# x-axis labels
ax.set_yticklabels(['1','2', '3', '4'])
 
# Adding title
#plt.title("Customized box plot")

#labels and legend
plt.xlabel('\% of youth abandoning the queue')
plt.ylabel(r'Shelter ID')

#plt.grid(axis = 'x', color = 'gray', linestyle = '--', linewidth = 0.2)

plt.grid(which='major', color='#DDDDDD', linewidth=0.8)
# Show the minor grid as well. Style it in very light gray as a thin,
# dotted line.
plt.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
# Make the minor ticks and gridlines show.
plt.minorticks_on()

plt.rcParams["font.family"] = "serif"
plt.rcParams.update({'font.size': 43})

plt.xlim([0,0.8])
 
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

textbox = '\n'.join(['RMI'])

bbox = dict(boxstyle='square', facecolor='lightsteelblue', alpha=0.6)
fig.text(0.03,0.95,textbox,fontsize=43,transform=ax.transAxes, bbox=bbox, 
verticalalignment='top')
     
     
# show plot
plt.show()
# Out:
#      Shelter  Mean % abandonment  Std dev % abandonment         N
# 0  Shelter 0               0.268                  0.037   451.800
# 1  Shelter 1               0.010                  0.003 1,205.400
# 2  Shelter 2               0.303                  0.029   198.600
# 3  Shelter 3               0.390                  0.027   279.100

# %%
#Test for abandonment rate equality 

alpha = 0.05 

#For gender groups
n_s0 = mean(df_rmi_arriving_s0)
n_s1 = mean(df_rmi_arriving_s1)
n_s2 = mean(df_rmi_arriving_s2)
n_s3 = mean(df_rmi_arriving_s3)

x_s0 = mean(df_rmi_arriving_s0)*mean(df_rmi_abandonment_s0)
x_s1 = mean(df_rmi_arriving_s1)*mean(df_rmi_abandonment_s1)
x_s2 = mean(df_rmi_arriving_s2)*mean(df_rmi_abandonment_s2)
x_s3 = mean(df_rmi_arriving_s3)*mean(df_rmi_abandonment_s3)

abandonment_cnts_01 = np.array([x_s0, x_s1])
total_cnts_01 = np.array([n_s0, n_s1])
test_stat_01, pval_01 = proportions_ztest(count=abandonment_cnts_01, nobs=total_cnts_01, alternative='two-sided')

abandonment_cnts_02 = np.array([x_s0, x_s2])
total_cnts_02 = np.array([n_s0, n_s2])
test_stat_02, pval_02 = proportions_ztest(count=abandonment_cnts_02, nobs=total_cnts_02, alternative='two-sided')

abandonment_cnts_03 = np.array([x_s0, x_s3])
total_cnts_03 = np.array([n_s0, n_s3])
test_stat_03, pval_03 = proportions_ztest(count=abandonment_cnts_03, nobs=total_cnts_03, alternative='two-sided')

abandonment_cnts_12 = np.array([x_s1, x_s2])
total_cnts_12 = np.array([n_s1, n_s2])
test_stat_12, pval_12 = proportions_ztest(count=abandonment_cnts_12, nobs=total_cnts_12, alternative='two-sided')

abandonment_cnts_13 = np.array([x_s1, x_s3])
total_cnts_13 = np.array([n_s1, n_s3])
test_stat_13, pval_13 = proportions_ztest(count=abandonment_cnts_13, nobs=total_cnts_13, alternative='two-sided')

abandonment_cnts_23 = np.array([x_s2, x_s3])
total_cnts_23 = np.array([n_s2, n_s3])
test_stat_23, pval_23 = proportions_ztest(count=abandonment_cnts_23, nobs=total_cnts_23, alternative='two-sided')

dict_abandonment_shelters = {'Comparisons' : ['Shelters 0-1','Shelters 0-2', 'Shelters 0-3', 'Shelters 1-2', 'Shelters 1-3', 'Shelters 2-3'],
        '95% confidence Interval' : [test_stat_01, test_stat_02, test_stat_03, test_stat_12, test_stat_13, test_stat_23],
        'p-value' : [pval_01, pval_02, pval_03, pval_12, pval_13, pval_23]
       }
pd.options.display.float_format = '{:,.3f}'.format
df_abandonments_shelters = pd.DataFrame(dict_abandonment_shelters)
  
# displaying the DataFrame
display(df_abandonments_shelters)
# Out:
#     Comparisons  95% confidence Interval  p-value
# 0  Shelters 0-1                   17.184    0.000
# 1  Shelters 0-2                   -0.915    0.360
# 2  Shelters 0-3                   -3.467    0.001
# 3  Shelters 1-2                  -17.288    0.000
# 4  Shelters 1-3                  -20.911    0.000
# 5  Shelters 2-3                   -1.974    0.048

# %% [markdown]
# ***Tests for Average Wait Time***

# %%
#Data for wait times

summary_table = pd.DataFrame(
    {'Characteristic': ['Male','Female', 'Non-cisgender', 'Older 21', 'Younger 21', 'Immigrant',
                        'NotImmigrant', 'HT', 'No HT'],
     'Mean wait time': [ mean(df_rmi_wait_male), mean(df_rmi_wait_female), mean(df_rmi_wait_noncis), 
                            mean(df_rmi_wait_older21), mean(df_rmi_wait_younger21), 
                        mean(df_rmi_wait_immigrant), mean(df_rmi_wait_notimmigrant), 
                            mean(df_rmi_wait_htvictim), mean(df_rmi_wait_nothtvictim)],
     'Std dev wait time': [statistics.stdev(df_rmi_wait_male), statistics.stdev(df_rmi_wait_female), statistics.stdev(df_rmi_wait_noncis), 
                              statistics.stdev(df_rmi_wait_older21), statistics.stdev(df_rmi_wait_younger21), 
                           statistics.stdev(df_rmi_wait_immigrant), statistics.stdev(df_rmi_wait_notimmigrant), 
                              statistics.stdev(df_rmi_wait_htvictim), statistics.stdev(df_rmi_wait_nothtvictim)],
     'N': [mean(df_rmi_arriving_male), mean(df_rmi_arriving_female), mean(df_rmi_arriving_noncis), 
                            mean(df_rmi_arriving_older21), mean(df_rmi_arriving_younger21), 
           mean(df_rmi_arriving_immigrant), mean(df_rmi_arriving_notimmigrant), 
                            mean(df_rmi_arriving_htvictim), mean(df_rmi_arriving_nothtvictim)]
    })
display(summary_table)

data_wait = [df_rmi_wait_female, df_rmi_wait_male, df_rmi_wait_noncis, df_rmi_wait_older21, df_rmi_wait_younger21, 
              df_rmi_wait_immigrant, df_rmi_wait_notimmigrant, df_rmi_wait_htvictim, df_rmi_wait_nothtvictim ]

#Figure that show the difference of wait times for different genders
#plt.rc('text', usetex=True)
#plt.rcParams['text.latex.preamble']=[r"\usepackage{amsmath}"]

fig = plt.figure(figsize =(10, 6))
ax = fig.add_subplot(111)
 
# Creating axes instance
bp = ax.boxplot(data_wait , patch_artist = True,
                notch ='True', vert = 0)
 
colors = ['indianred', 'indianred','indianred','#fc8d59', '#fc8d59', '#fee090','#fee090', '#91bfdb','#91bfdb']
 
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
 
# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='black',
                linewidth = 1.5,linestyle =":")
 
# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='black', linewidth = 2)
 
# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='black', linewidth = 3)
 
# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='black', alpha = 0.5)
     
# x-axis labels
ax.set_yticklabels(['Cisgender Man/Boy','Cisgender Woman/Girl', 'Non-Cisgender, LGBTQ+', 'Older than 21', 'Younger than 21',  'Immigrant',
                        'Not Immigrant', 'HT Victim', 'Not HT Victim'])
 
# Adding title
#plt.title("Customized box plot")

#labels and legend
plt.xlabel('Average wait time of youth (days)')
#plt.ylabel(r'Characteristic')

#plt.grid(axis = 'x', color = 'gray', linestyle = '--', linewidth = 0.2)

plt.grid(which='major', color='#DDDDDD', linewidth=0.8)
# Show the minor grid as well. Style it in very light gray as a thin,
# dotted line.
plt.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
# Make the minor ticks and gridlines show.
plt.minorticks_on()

plt.rcParams["font.family"] = "serif"
plt.rcParams.update({'font.size': 26})

plt.xlim([0,4])
 
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

textbox = '\n'.join(['RMI'])

bbox = dict(boxstyle='square', facecolor='lightsteelblue', alpha=0.6)
fig.text(0.87,0.95,textbox,fontsize=26,transform=ax.transAxes, bbox=bbox, 
verticalalignment='top')
     
# show plot
plt.show()


# #Plot the means
# sns.pointplot(x = 'Characteristic', y = 'Mean % abandoning', data = summary_table, palette= sns.color_palette("Set2"))
# plt.grid(axis = 'both', color = 'gray', linestyle = '--', linewidth = 0.2)
# plt.show()
# Out:
#   Characteristic  Mean wait time  Std dev wait time         N
# 0           Male           0.309              0.037   783.400
# 1         Female           0.318              0.051   629.900
# 2  Non-cisgender           1.051              0.278   475.400
# 3       Older 21           1.553              0.244   196.700
# 4     Younger 21           0.374              0.040 1,935.200
# 5      Immigrant           0.466              0.045   301.100
# 6   NotImmigrant           0.466              0.045 1,830.800
# 7             HT           0.504              0.081   437.200
# 8          No HT           0.442              0.042 1,694.700

# %% [markdown]
# __Information Regarding T Test function__
#  - 'T': T-value
#  - 'dof': degrees of freedom
#  - 'alternative': alternative of the test
#  - 'p-val': p-value
#  - 'CI95%': confidence intervals of the difference in means
#  - 'cohen-d': Cohen d effect size
#  - 'BF10': Bayes Factor of the alternative hypothesis
#  - 'power': achieved power of the test ( = 1 - type II error)

# %%
#Test for wait time equality 

alpha = 0.05 

#For gender groups
ttest_mf = ttest(df_rmi_wait_male, df_rmi_wait_female, correction = True)
ttest_mn = ttest(df_rmi_wait_male, df_rmi_wait_noncis, correction = True)
ttest_fn = ttest(df_rmi_wait_female, df_rmi_wait_noncis, correction = True)
ttest_age = ttest(df_rmi_wait_older21, df_rmi_wait_younger21, correction = True)
ttest_child = ttest(df_rmi_wait_withchild, df_rmi_wait_nochild, correction = True)
ttest_immigrant = ttest(df_rmi_wait_immigrant, df_rmi_wait_notimmigrant, correction = True)
ttest_htvictim = ttest(df_rmi_wait_htvictim, df_rmi_wait_nothtvictim, correction = True)

dict_abandonment = {'Comparisons' : ['Male-Female','Male-NonCisgender','Female-NonCisgender','Age','Having a Child',
                                                'Being an immigrant','Experiencing HT'],
        '95% confidence Interval' : [ttest_mf['CI95%'].values[0], ttest_mn['CI95%'].values[0], ttest_fn['CI95%'].values[0],
                                     ttest_age['CI95%'].values[0], ttest_child['CI95%'].values[0], ttest_immigrant['CI95%'].values[0], 
                                    ttest_htvictim['CI95%'].values[0]],
        'p-value' : [ttest_mf['p-val'].values[0], ttest_mn['p-val'].values[0], ttest_fn['p-val'].values[0],
                                     ttest_age['p-val'].values[0], ttest_child['p-val'].values[0], ttest_immigrant['p-val'].values[0], 
                                    ttest_htvictim['p-val'].values[0]]
       }
pd.options.display.float_format = '{:,.3f}'.format
df_abandonments = pd.DataFrame(dict_abandonment)
  
# displaying the DataFrame
display(df_abandonments)
# Out:
#            Comparisons 95% confidence Interval  p-value
# 0          Male-Female            [-0.02, 0.0]    0.123
# 1    Male-NonCisgender           [-0.8, -0.69]    0.000
# 2  Female-NonCisgender          [-0.79, -0.68]    0.000
# 3                  Age            [1.13, 1.23]    0.000
# 4       Having a Child           [-0.2, -0.16]    0.000
# 5   Being an immigrant           [-0.01, 0.01]    1.000
# 6      Experiencing HT            [0.04, 0.08]    0.000

# %%
summary_table = pd.DataFrame(
    {'Shelter': ['Shelter 0','Shelter 1', 'Shelter 2', 'Shelter 3'],
     'Mean wait time': [ mean(df_rmi_wait_s0), mean(df_rmi_wait_s1), mean(df_rmi_wait_s2), mean(df_rmi_wait_s3)],
     'Std dev wait time': [statistics.stdev(df_rmi_wait_s0), statistics.stdev(df_rmi_wait_s1), statistics.stdev(df_rmi_wait_s2), statistics.stdev(df_rmi_wait_s3)],
     'N': [mean(df_rmi_arriving_s0), mean(df_rmi_arriving_s1), mean(df_rmi_arriving_s2), mean(df_rmi_arriving_s3)]
    })
display(summary_table)

data_wait = [df_rmi_wait_s0, df_rmi_wait_s1, df_rmi_wait_s2, df_rmi_wait_s3]

fig = plt.figure(figsize =(10, 6))
ax = fig.add_subplot(111)
 
# Creating axes instance
bp = ax.boxplot(data_wait , patch_artist = True,
                notch ='True', vert = 0)
 
colors = ['#bae4bc', '#bae4bc','#bae4bc', '#bae4bc']
 
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
 
# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='black',
                linewidth = 1.5,linestyle =":")
 
# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='black', linewidth = 2)
 
# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='black', linewidth = 3)
 
# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='black', alpha = 0.5)
     
# x-axis labels
ax.set_yticklabels(['1','2', '3', '4'])
 
# Adding title
#plt.title("Customized box plot")

#labels and legend
plt.xlabel('Average wait time of youth (days)')
plt.ylabel(r'Shelter ID')

#plt.grid(axis = 'x', color = 'gray', linestyle = '--', linewidth = 0.2)

plt.grid(which='major', color='#DDDDDD', linewidth=0.8)
# Show the minor grid as well. Style it in very light gray as a thin,
# dotted line.
plt.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
# Make the minor ticks and gridlines show.
plt.minorticks_on()

plt.rcParams["font.family"] = "serif"
plt.rcParams.update({'font.size': 43})

plt.xlim([0,5])
 
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

textbox = '\n'.join(['RMI'])

bbox = dict(boxstyle='square', facecolor='lightsteelblue', alpha=0.6)
fig.text(0.03,0.95,textbox,fontsize=43,transform=ax.transAxes, bbox=bbox, 
verticalalignment='top')

# show plot
plt.show()
# Out:
#      Shelter  Mean wait time  Std dev wait time         N
# 0  Shelter 0           1.099              0.299   451.800
# 1  Shelter 1           0.050              0.005 1,205.400
# 2  Shelter 2           0.853              0.218   198.600
# 3  Shelter 3           1.748              0.260   279.100

# %%
#Test for abandonment rate equality 

alpha = 0.05 

#For gender groups
ttest_01 = ttest(df_rmi_wait_s0, df_rmi_wait_s1, correction = True)
ttest_02 = ttest(df_rmi_wait_s0, df_rmi_wait_s2, correction = True)
ttest_03 = ttest(df_rmi_wait_s0, df_rmi_wait_s3, correction = True)
ttest_12 = ttest(df_rmi_wait_s1, df_rmi_wait_s2, correction = True)
ttest_13 = ttest(df_rmi_wait_s1, df_rmi_wait_s3, correction = True)
ttest_23 = ttest(df_rmi_wait_s2, df_rmi_wait_s3, correction = True)

dict_abandonment_shelters = {'Comparisons' : ['Shelters 0-1','Shelters 0-2', 'Shelters 0-3', 'Shelters 1-2', 'Shelters 1-3', 'Shelters 2-3'],
        '95% confidence Interval' : [ttest_01['CI95%'].values[0], ttest_02['CI95%'].values[0], ttest_03['CI95%'].values[0],
                                     ttest_12['CI95%'].values[0], ttest_13['CI95%'].values[0], ttest_23['CI95%'].values[0]],
        'p-value' : [ttest_01['p-val'].values[0], ttest_02['p-val'].values[0], ttest_03['p-val'].values[0],
                                     ttest_12['p-val'].values[0], ttest_13['p-val'].values[0], ttest_23['p-val'].values[0]]
       }
pd.options.display.float_format = '{:,.3f}'.format
df_abandonments_shelters = pd.DataFrame(dict_abandonment_shelters)
  
# displaying the DataFrame
display(df_abandonments_shelters)
# Out:
#     Comparisons 95% confidence Interval  p-value
# 0  Shelters 0-1            [0.99, 1.11]    0.000
# 1  Shelters 0-2            [0.17, 0.32]    0.000
# 2  Shelters 0-3          [-0.73, -0.57]    0.000
# 3  Shelters 1-2          [-0.85, -0.76]    0.000
# 4  Shelters 1-3          [-1.75, -1.65]    0.000
# 5  Shelters 2-3          [-0.96, -0.83]    0.000

# %%
#Utilization

data_utilization = [df_rmi_utilization_s0, df_rmi_utilization_s1, df_rmi_utilization_s2, df_rmi_utilization_s3]

fig = plt.figure(figsize =(10, 6))
ax = fig.add_subplot(111)
 
# Creating axes instance
bp = ax.boxplot(data_utilization , patch_artist = True,
                notch ='True', vert = 0)
 
colors = ['#bae4bc', '#bae4bc','#bae4bc', '#bae4bc']
 
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
 
# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='black',
                linewidth = 1.5,linestyle =":")
 
# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='black', linewidth = 2)
 
# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='black', linewidth = 3)
 
# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='black', alpha = 0.5)
     
# x-axis labels
ax.set_yticklabels(['1','2', '3', '4'])
 
# Adding title
#plt.title("Customized box plot")

#labels and legend
plt.xlabel('Server utilization')
plt.ylabel(r'Shelter ID')

#plt.grid(axis = 'x', color = 'gray', linestyle = '--', linewidth = 0.2)

plt.grid(which='major', color='#DDDDDD', linewidth=0.8)
# Show the minor grid as well. Style it in very light gray as a thin,
# dotted line.
plt.grid(which='minor', color='#EEEEEE', linestyle=':', linewidth=0.5)
# Make the minor ticks and gridlines show.
plt.minorticks_on()

plt.rcParams["font.family"] = "serif"
plt.rcParams.update({'font.size': 43})

plt.xlim([0,1])
 
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

textbox = '\n'.join(['RMI'])

bbox = dict(boxstyle='square', facecolor='lightsteelblue', alpha=0.6)
fig.text(0.03,0.95,textbox,fontsize=43,transform=ax.transAxes, bbox=bbox, 
verticalalignment='top')
     
# show plot
plt.show()
